# %% [markdown]
# <a href="https://colab.research.google.com/github/pszemraj/ai-msgbot/blob/main/notebooks/colab-notebooks/GPT2_general_conv_textgen_training_GPU.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ##  aitextgen — Train a GPT-2 (or GPT Neo) Text-Generating Model w/ GPU
#
# This notebook is based on the original tutorial from `aitextgen`!
#
# - For more about `aitextgen`, you can visit [this GitHub repository](https://github.com/minimaxir/aitextgen) or [read the documentation](https://docs.aitextgen.io/).
# - for `ai-msgbot` (which is using `aitextgen` for chatbot-esque purposes) you can find the project repo [here](https://github.com/pszemraj/ai-msgbot)
#
#
# _updates made by [Peter](https://peterszemraj.ch/)_

# %% [markdown]
# ---

# %% [markdown]
# ### GPU
#
# Colaboratory uses a Nvidia K80, an Nvidia P100, an Nvidia V100, or Nvidia A100. For finetuning GPT-2 124M, any of these GPUs will be fine, but for text generation, a k80 or a P100 is ideal since they have more VRAM.
#
# - In theory: **If you receive a T4 or a V100 GPU, you can enable `fp16=True` during training for faster/more memory efficient training.**

# %%
# !nvidia-smi
# Out:
# Thu Nov 25 04:11:25 2021
# +-----------------------------------------------------------------------------+
# | NVIDIA-SMI 495.44       Driver Version: 460.32.03    CUDA Version: 11.2     |
# |-------------------------------+----------------------+----------------------+
# | GPU  Name        Persistence-M| Bus-Id        Disp.A | Volatile Uncorr. ECC |
# | Fan  Temp  Perf  Pwr:Usage/Cap|         Memory-Usage | GPU-Util  Compute M. |
# |                               |                      |               MIG M. |
# |===============================+======================+======================|
# |   0  Tesla V100-SXM2...  Off  | 00000000:00:04.0 Off |                    0 |
# | N/A   35C    P0    23W / 300W |      0MiB / 16160MiB |      0%      Default |
# |                               |                      |                  N/A |
# +-------------------------------+----------------------+----------------------+
#
# +-----------------------------------------------------------------------------+
# | Processes:                                                                  |
# |  GPU   GI   CI        PID   Type   Process name                  GPU Memory |
# |        ID   ID                                                   Usage      |
# |=============================================================================|
# |  No running processes found                                                 |
# +-----------------------------------------------------------------------------+

# %% [markdown]
# ### formatting

# %%
from IPython.display import HTML, display
# colab formatting
def set_css():
    display(
        HTML(
            """
  <style>
    pre {
        white-space: pre-wrap;
    }
  </style>
  """
        )
    )

get_ipython().events.register("pre_run_cell", set_css)

# %% [markdown]
# ## setup

# %%
# update torch in case using a A100 GPU
# may take 5+ minutes
# !pip3 install torch==1.10.0+cu113 torchvision==0.11.1+cu113 -f https://download.pytorch.org/whl/cu113/torch_stable.html -q
# Out:
#   <style>
#     pre {
#         white-space: pre-wrap;
#     }
#   </style>
#      |██████████████▋                 | 834.1 MB 1.2 MB/s eta 0:13:35tcmalloc: large alloc 1147494400 bytes == 0x562b323f4000 @  0x7f4d37e1c615 0x562af9bf34cc 0x562af9cd347a 0x562af9bf62ed 0x562af9ce7e1d 0x562af9c69e99 0x562af9c649ee 0x562af9bf7bda 0x562af9c69d00 0x562af9c649ee 0x562af9bf7bda 0x562af9c66737 0x562af9ce8c66 0x562af9c65daf 0x562af9ce8c66 0x562af9c65daf 0x562af9ce8c66 0x562af9c65daf 0x562af9bf8039 0x562af9c3b409 0x562af9bf6c52 0x562af9c69c25 0x562af9c649ee 0x562af9bf7bda 0x562af9c66737 0x562af9c649ee 0x562af9bf7bda 0x562af9c65915 0x562af9bf7afa 0x562af9c65c0d 0x562af9c649ee
#      |██████████████████▌             | 1055.7 MB 57.1 MB/s eta 0:00:14tcmalloc: large alloc 1434370048 bytes == 0x562b76a4a000 @  0x7f4d37e1c615 0x562af9bf34cc 0x562af9cd347a 0x562af9bf62ed 0x562af9ce7e1d 0x562af9c69e99 0x562af9c649ee 0x562af9bf7bda 0x562af9c69d00 0x562af9c649ee 0x562af9bf7bda 0x562af9c66737 0x562af9ce8c66 0x562af9c65daf 0x562af9ce8c66 0x562af9c65daf 0x562af9ce8c66 0x562af9c65daf 0x562af9bf8039 0x562af9c3b409 0x562af9bf6c52 0x562af9c69c25 0x562af9c649ee 0x562af9bf7bda 0x562af9c66737 0x562af9c649ee 0x562af9bf7bda 0x562af9c65915 0x562af9bf7afa 0x562af9c65c0d 0x562af9c649ee
#      |███████████████████████▌        | 1336.2 MB 1.2 MB/s eta 0:06:38tcmalloc: large alloc 1792966656 bytes == 0x562afb87c000 @  0x7f4d37e1c615 0x562af9bf34cc 0x562af9cd347a 0x562af9bf62ed 0x562af9ce7e1d 0x562af9c69e99 0x562af9c649ee 0x562af9bf7bda 0x562af9c69d00 0x562af9c649ee 0x562af9bf7bda 0x562af9c66737 0x562af9ce8c66 0x562af9c65daf 0x562af9ce8c66 0x562af9c65daf 0x562af9ce8c66 0x562af9c65daf 0x562af9bf8039 0x562af9c3b409 0x562af9bf6c52 0x562af9c69c25 0x562af9c649ee 0x562af9bf7bda 0x562af9c66737 0x562af9c649ee 0x562af9bf7bda 0x562af9c65915 0x562af9bf7afa 0x562af9c65c0d 0x562af9c649ee
#      |█████████████████████████████▊  | 1691.1 MB 1.2 MB/s eta 0:01:52tcmalloc: large alloc 2241208320 bytes == 0x562b66664000 @  0x7f4d37e1c615 0x562af9bf34cc 0x562af9cd347a 0x562af9bf62ed 0x562af9ce7e1d 0x562af9c69e99 0x562af9c649ee 0x562af9bf7bda 0x562af9c69d00 0x562af9c649ee 0x562af9bf7bda 0x562af9c66737 0x562af9ce8c66 0x562af9c65daf 0x562af9ce8c66 0x562af9c65daf 0x562af9ce8c66 0x562af9c65daf 0x562af9bf8039 0x562af9c3b409 0x562af9bf6c52 0x562af9c69c25 0x562af9c649ee 0x562af9bf7bda 0x562af9c66737 0x562af9c649ee 0x562af9bf7bda 0x562af9c65915 0x562af9bf7afa 0x562af9c65c0d 0x562af9c649ee
#      |████████████████████████████████| 1821.5 MB 1.2 MB/s eta 0:00:01tcmalloc: large alloc 1821458432 bytes == 0x562bebfc6000 @  0x7f4d37e1b1e7 0x562af9c29067 0x562af9bf34cc 0x562af9cd347a 0x562af9bf62ed 0x562af9ce7e1d 0x562af9c69e99 0x562af9c649ee 0x562af9bf7bda 0x562af9c65c0d 0x562af9c649ee 0x562af9bf7bda 0x562af9c65c0d 0x562af9c649ee 0x562af9bf7bda 0x562af9c65c0d 0x562af9c649ee 0x562af9bf7bda 0x562af9c65c0d 0x562af9c649ee 0x562af9bf7bda 0x562af9c65c0d 0x562af9bf7afa 0x562af9c65c0d 0x562af9c649ee 0x562af9bf7bda 0x562af9c66737 0x562af9c649ee 0x562af9bf7bda 0x562af9c66737 0x562af9c649ee
# tcmalloc: large alloc 2276827136 bytes == 0x562c588da000 @  0x7f4d37e1c615 0x562af9bf34cc 0x562af9cd347a 0x562af9bf62ed 0x562af9ce7e1d 0x562af9c69e99 0x562af9c649ee 0x562af9bf7bda 0x562af9c65c0d 0x562af9c649ee 0x562af9bf7bda 0x562af9c65c0d 0x562af9c649ee 0x562af9bf7bda 0x562af9c65c0d 0x562af9c649ee 0x562af9bf7bda 0x562af9c65c0d 0x562af9c649ee 0x562af9bf7bda 0x562af9c65c0d 0x562af9bf7afa 0x562af9c65c0d 0x562af9c649ee 0x562af9bf7bda 0x562af9c66737 0x562af9c649ee 0x562af9bf7bda 0x562af9c66737 0x562af9c649ee 0x562af9bf8271
#      |████████████████████████████████| 1821.5 MB 4.7 kB/s
#      |████████████████████████████████| 24.6 MB 1.1 MB/s

# %%
# !pip install -q aitextgen

import logging

logging.basicConfig(
    format="%(asctime)s — %(levelname)s — %(name)s — %(message)s",
    datefmt="%m/%d/%Y %H:%M:%S",
    level=logging.INFO,
)

from aitextgen import aitextgen
from aitextgen.colab import mount_gdrive, copy_file_from_gdrive
# Out:
#   <style>
#     pre {
#         white-space: pre-wrap;
#     }
#   </style>
#      |████████████████████████████████| 572 kB 13.5 MB/s
#      |████████████████████████████████| 3.1 MB 51.0 MB/s
#      |████████████████████████████████| 87 kB 7.6 MB/s
#      |████████████████████████████████| 523 kB 50.5 MB/s
#      |████████████████████████████████| 329 kB 69.9 MB/s
#      |████████████████████████████████| 596 kB 52.1 MB/s
#      |████████████████████████████████| 829 kB 55.0 MB/s
#      |████████████████████████████████| 132 kB 71.3 MB/s
#      |████████████████████████████████| 1.1 MB 50.9 MB/s
#      |████████████████████████████████| 3.3 MB 69.8 MB/s
#      |████████████████████████████████| 59 kB 7.4 MB/s
#      |████████████████████████████████| 895 kB 53.8 MB/s
#      |████████████████████████████████| 160 kB 88.3 MB/s
#      |████████████████████████████████| 192 kB 87.6 MB/s
#      |████████████████████████████████| 271 kB 80.4 MB/s
#   Building wheel for aitextgen (setup.py) ... done
#   Building wheel for fire (setup.py) ... done
#   Building wheel for future (setup.py) ... done

# %%
mount_gdrive()
# Out:
#   <style>
#     pre {
#         white-space: pre-wrap;
#     }
#   </style>
# Mounted at /content/drive

# %% [markdown]
# ### Loading GPT-2 or GPT Neo
#
#
# - A common use case is *continuing* to fine-tune a model that was originally pretrained, and then fine-tuned a little bit, but needs to be fine-tuned more for accuracy/saliency reasons or because Google cut off the runtime earlier.
#     - in this case, `load_from_folder` should be set to `True` and `load_folder_dir` points to where the model checkpoint is on your google drive.
# - **the below section describes loading an new/pretrained model from the original tutorial.**
#
# > If you're retraining a model on new text, you need to download and load the GPT-2 model into the GPU.
#
# > There are several sizes of GPT-2:
#
#     * `124M` (default): the "small" model, 500MB on disk.
#     * `355M` (default): the "medium" model, 1.5GB on disk.
#     * `774M` (default): the "large" model, 3GB on disk.
#
# > You can also finetune a GPT Neo model instead ([_or any textgen GPT-architecture model on huggingface_](https://huggingface.co/models?pipeline_tag=text-generation)), which is more suitable for longer texts and the base model has more recent data:
#
# * `125M`: Analogous to the GPT-2 124M model. (355M parameter model was removed)
# *  `EleutherAI/gpt-neo-1.3B` : 1.3 billion parameter model. Have yet to see this train on Colab without crashing
#
# > The next cell downloads the model and saves it in the Colaboratory VM. If the model has already been downloaded, running this cell will reload it.

# %% [markdown]
# ##

# %%
model_size = "774M" #@param ["355M", "774M"]
load_from_folder = True #@param {type:"boolean"}
load_folder_dir = "/content/drive/MyDrive/Programming/AI_peter/gpt2-25KtriviaQA100KnaturalQA50Kdailydialogues-774M" #@param {type:"string"}
# Out:
#   <style>
#     pre {
#         white-space: pre-wrap;
#     }
#   </style>

# %%
if load_from_folder:
    ai = aitextgen(model_folder=load_folder_dir, to_gpu=True,
                   gradient_checkpointing=True)
else:
    ai = aitextgen(tf_gpt2=model_size, to_gpu=True,
                   gradient_checkpointing=True)
# Comment out the above line and uncomment the below line to use GPT Neo instead.
# ai = aitextgen(model='distilgpt2', 
#                to_gpu=True, 
#                gradient_checkpointing=True)
# Out:
#   <style>
#     pre {
#         white-space: pre-wrap;
#     }
#   </style>
# 11/25/2021 04:17:05 — INFO — aitextgen — Loading model from provided weights and config in //content/drive/MyDrive/Programming/AI_peter/gpt2-25KtriviaQA100KnaturalQA50Kdailydialogues-774M.
# /usr/local/lib/python3.7/dist-packages/transformers/configuration_utils.py:341: UserWarning: Passing `gradient_checkpointing` to a config initialization is deprecated and will be removed in v5 Transformers. Using `model.gradient_checkpointing_enable()` instead, or if you are using the `Trainer` API, pass `gradient_checkpointing=True` in your `TrainingArguments`.
#   "Passing `gradient_checkpointing` to a config initialization is deprecated and will be removed in v5 "
# 11/25/2021 04:17:40 — INFO — aitextgen — GPT2 loaded with 774M parameters.
# 11/25/2021 04:17:40 — INFO — aitextgen — Gradient checkpointing enabled for model training.
# 11/25/2021 04:17:40 — INFO — aitextgen — Using the default GPT-2 Tokenizer.

# %% [markdown]
# ### load training data
#
#
# - <font color="orange"> combine any other data from the a "standard" conversational dataset and do a final pass of training (with different data) </font>

# %%
dl_link = "https://github.com/pszemraj/ai-msgbot/raw/main/conversation-data/wizard-of-wikipedia/ScriptParse-wow-train-kilt.txt" #@param {type:"string"}
# Out:
#   <style>
#     pre {
#         white-space: pre-wrap;
#     }
#   </style>

# %%
# download test image
from urllib import request
from os.path import join
import os
vm_wd = os.getcwd()
local_name = join(vm_wd, "training_script.txt")
request.urlretrieve(dl_link, local_name)
# Out:
#   <style>
#     pre {
#         white-space: pre-wrap;
#     }
#   </style>
# ('/content/training_script.txt', <http.client.HTTPMessage at 0x7faf9fa507d0>)

# %%
# adjust names in script if needed  
import pprint as pp
from os.path import basename

def update_script_names(local_name, spkr_from="speaker a", spkr_to="person beta",
                        resp_from="speaker b", resp_to="nancy sellers",
                        verbose=False):
    """
    update_script_names - if the textfile script has different names for the 
    speaker/responder than desired (i.e. it is a group conversation, and the 
    chatbot is just supposed to simulate 1:1) this function can be used to 
    standardize
    """

    with open(local_name, 'r', encoding='utf-8', errors='ignore') as fi:
        orig_lines = fi.readlines()

    from tqdm.auto import tqdm

    upd_lines = []

    for line in tqdm(orig_lines, total=len(orig_lines), 
                     desc="replacing speaker names"):
        
        fixline = line.replace(spkr_from, spkr_to)
        fixline = fixline.replace(resp_from, resp_to)
        upd_lines.append(fixline)

    local_namev2 = join(vm_wd, "V2-rename-" + basename(local_name))

    with open(local_namev2, 'w', encoding='utf-8', errors='ignore') as fo:
        fo.writelines(upd_lines)

    if verbose: pp.pprint(upd_lines[:10])
    # return filepath
    return local_namev2
# Out:
#   <style>
#     pre {
#         white-space: pre-wrap;
#     }
#   </style>

# %%
file_name = local_name # update if using fn above
# Out:
#   <style>
#     pre {
#         white-space: pre-wrap;
#     }
#   </style>

# %% [markdown]
# ## Train / Finetune GPT-2
#
# The next cell will start the actual finetuning of GPT-2 in aitextgen. It runs for `num_steps`, and a progress bar will appear to show training progress, current loss (the lower the better the model), and average loss (to give a sense on loss trajectory).
#
# The model will be saved every `save_every` steps in `trained_model` by default, and when training completes. If you mounted your Google Drive, the model will _also_ be saved there in a unique folder.
#
# The training might time out after 4ish hours; if you did not mount to Google Drive, make sure you end training and save the results so you don't lose them! (if this happens frequently, you may want to consider using [Colab Pro](https://colab.research.google.com/signup))
#
# Important parameters for `train()`:
#
# - **`line_by_line`**: Set this to `True` if the input text file is a single-column CSV, with one record per row. aitextgen will automatically process it optimally.
# - **`from_cache`**: If you compressed your dataset locally (as noted in the previous section) and are using that cache file, set this to `True`.
# - **`num_steps`**: Number of steps to train the model for.
# - **`generate_every`**: Interval of steps to generate example text from the model; good for qualitatively validating training.
# - **`save_every`**: Interval of steps to save the model: the model will be saved in the VM to `/trained_model`.
# - **`save_gdrive`**: Set this to `True` to copy the model to a unique folder in your Google Drive, if you have mounted it in the earlier cells
# - **`fp16`**: Enables half-precision training for faster/more memory-efficient training. Only works on a T4 or V100 GPU.
#
# Here are other important parameters for `train()` that are useful but you likely do not need to change.
#
# - **`learning_rate`**: Learning rate of the model training.
# - **`batch_size`**: Batch size of the model training; setting it too high will cause the GPU to go OOM. (if using `fp16`, you can increase the batch size more safely)

# %%
base_dir = "/content/drive/MyDrive/Programming/ai-msgbot" #@param {type:"string"}
# update to yours
# Out:
#   <style>
#     pre {
#         white-space: pre-wrap;
#     }
#   </style>

# %%
import gc, os
from os.path import join
from datetime import datetime

def get_timestamp():
    return datetime.now().strftime("%b-%d-%Y_t-%H")

temp_gpu_path = join(base_dir, 
                     "GPT2-conversational-{sz}-{dt}".format(sz=model_size,
                                                            dt=get_timestamp(),
                                                            )
                     )
os.makedirs(temp_gpu_path, exist_ok=True)
gc.collect()
# Out:
#   <style>
#     pre {
#         white-space: pre-wrap;
#     }
#   </style>
# 0

# %% [markdown]
# ### example outputs
#
# - this cell had its outputs cleared before notebook was posted.
# - the below is an example of what the outputs during training should look like.
#
# ```
# 1,000 steps reached: saving model to //content/drive/MyDrive/Programming/ai-msgbot/GPT2-conversational-355M-Nov-23-2021_t-04
# 1,500 steps reached: generating sample texts.
# /usr/local/lib/python3.7/dist-packages/torch/utils/checkpoint.py:25: UserWarning: None of the inputs have requires_grad=True. Gradients will be None
#   warnings.warn("None of the inputs have requires_grad=True. Gradients will be None")
# ==========
# .
#
# person alpha:
# i love to read. reading. reading requires creativity. it's one of the intricacies of decoding symbols and improving knowledge, sharing information through wires and wires.
# is reading still a good thing to read?
# not really. reading software allows creativity, refinement and development. it's also a great tool for sharing information and sharing information over the past.
# can you give example of reading strategies?
#
# person beta:
# its is. reading produces creativity. it's my favorite form of reading, it's used on high shelfs.
#
# person alpha:
# do you like to eat at a restaurant? i'm a big fan of cooking and watching my favorite meal.
# i love cooking, it is the combination of grilling over an open fire.
# i love cooking, it is so good! it's my favorite meal of the day. i like to add to my food in my house.
# it is a great meal too, i like to add many different ways to cooking.
# i like to add different ways to cooking.
# i agree, it is the most common type of cooking.
#
# person beta:
# i like to add different techniques and ingredients and ingredients.
#
# person alpha:
#
# ==========
# 2,000 steps reached: saving model to //content/drive/MyDrive/Programming/ai-msgbot/GPT2-conversational-355M-Nov-23-2021_t-04
# 3,000 steps reached: saving model to //content/drive/MyDrive/Programming/ai-msgbot/GPT2-conversational-355M-Nov-23-2021_t-04
# 3,000 steps reached: generating sample texts.
# ==========
#
#
# person alpha:
# i love to cook. cooking is a great art. you can bake!
# i love cooking too. cooking as a whole is an art.
# ```

# %% [markdown]
# ### t r a i n

# %%
# DO NOT USE WARMUP STEPS

ai.train(
            file_name, # text file with training data
            output_dir=temp_gpu_path, # where it saves during "save_every"
            line_by_line=False, # if using CSV file input
            from_cache=False,
            num_steps=80000, # takes about 5 hours on 16 gb v100 GPU for 75000
            generate_every=1500,
            max_grad_norm=0.5,
            save_every=1000,
            gradient_accumulation_steps=1,
            save_gdrive=False, # this is an "automated" save which is worse than current method (IMO)
            learning_rate=1e-3,
        #  fp16=True, # may be relevant to set to false (even if available) for "final" training
            batch_size=1, # if pushing model_size you probably want to leave this at 1
        #  fp16_opt_level="O2", # different types of FP16 are possible
        #  amp_backend='apex'
        )
# Out:
#   <style>
#     pre {
#         white-space: pre-wrap;
#     }
#   </style>
# 11/25/2021 04:17:49 — INFO — aitextgen — Loading text from /content/training_script.txt with generation length of 1024.
#   0%|          | 0/1050198 [00:00<?, ?it/s]
# 11/25/2021 04:17:50 — INFO — aitextgen.TokenDataset — Encoding 1,050,198 sets of tokens from /content/training_script.txt.
# /usr/local/lib/python3.7/dist-packages/pytorch_lightning/trainer/connectors/callback_connector.py:148: LightningDeprecationWarning: Setting `Trainer(checkpoint_callback=False)` is deprecated in v1.5 and will be removed in v1.7. Please consider using `Trainer(enable_checkpointing=False)`.
#   f"Setting `Trainer(checkpoint_callback={checkpoint_callback})` is deprecated in v1.5 and will "
# /usr/local/lib/python3.7/dist-packages/pytorch_lightning/trainer/connectors/callback_connector.py:91: LightningDeprecationWarning: Setting `Trainer(progress_bar_refresh_rate=20)` is deprecated in v1.5 and will be removed in v1.7. Please pass `pytorch_lightning.callbacks.progress.TQDMProgressBar` with `refresh_rate` directly to the Trainer's `callbacks` argument instead. Or, to disable the progress bar pass `enable_progress_bar = False` to the Trainer.
#   f"Setting `Trainer(progress_bar_refresh_rate={progress_bar_refresh_rate})` is deprecated in v1.5 and"
# /usr/local/lib/python3.7/dist-packages/pytorch_lightning/trainer/connectors/callback_connector.py:168: LightningDeprecationWarning: Setting `Trainer(weights_summary=None)` is deprecated in v1.5 and will be removed in v1.7. Please set `Trainer(enable_model_summary=False)` instead.
#   "Setting `Trainer(weights_summary=None)` is deprecated in v1.5 and will be removed"
# 11/25/2021 04:18:05 — INFO — pytorch_lightning.utilities.distributed — GPU available: True, used: True
# 11/25/2021 04:18:05 — INFO — pytorch_lightning.utilities.distributed — TPU available: False, using: 0 TPU cores
# 11/25/2021 04:18:05 — INFO — pytorch_lightning.utilities.distributed — IPU available: False, using: 0 IPUs
# 11/25/2021 04:18:05 — INFO — pytorch_lightning.accelerators.gpu — LOCAL_RANK: 0 - CUDA_VISIBLE_DEVICES: [0]
#   0%|          | 0/80000 [00:00<?, ?it/s]
# /usr/local/lib/python3.7/dist-packages/pytorch_lightning/trainer/trainer.py:1819: LightningDeprecationWarning: `trainer.progress_bar_dict` is deprecated in v1.5 and will be removed in v1.7. Use `ProgressBarBase.get_metrics` instead.
#   "`trainer.progress_bar_dict` is deprecated in v1.5 and will be removed in v1.7."
# 1,000 steps reached: saving model to //content/drive/MyDrive/Programming/ai-msgbot/GPT2-conversational-774M-Nov-25-2021_t-04
# 1,500 steps reached: generating sample texts.
# /usr/local/lib/python3.7/dist-packages/torch/utils/checkpoint.py:25: UserWarning: None of the inputs have requires_grad=True. Gradients will be None
#   warnings.warn("None of the inputs have requires_grad=True. Gradients will be None")
# ==========
#
#
# person alpha:
# do you enjoy the movie?
#
# person beta:
# yes, i love the film is based in george r. r. martin scotland
#
# person alpha:
# oh cool, how does it get to be one?
#
# person beta:
# well it was a break between a single.
#
# person alpha:
# i really like the show but i don't know much about it, i do not know much about it
#
# person beta:
# i know there are many episodes for the show, and the show has to be the highest grosss in the show though.
#
# person alpha:
# i've been a new game of thrones, or twice a year
#
# person beta:
# i dont really say the big leagues. "american", is the ones that was created by benioff, paul hiller and the shissshoukaman.
#
# person alpha:
# what's your opinion on the beat team?
#
# person beta:
# i think mary, the beat team is the beat of the mavericks.
#
# person alpha:
# do you like hockey?
#
# person beta:
# i love tennis, can you tell me more?
# ==========
# 2,000 steps reached: saving model to //content/drive/MyDrive/Programming/ai-msgbot/GPT2-conversational-774M-Nov-25-2021_t-04
# 3,000 steps reached: saving model to //content/drive/MyDrive/Programming/ai-msgbot/GPT2-conversational-774M-Nov-25-2021_t-04
# 3,000 steps reached: generating sample texts.
# ==========
#  but i'm so scared of a pizza!
#
# person alpha:
# i love the taste of it's my favorite food. in fact i am an american.
#
# person beta:
# the word "burgerin" means soft hot or something similar to something else.
#
# person alpha:
# yeah i think the word "pizza" is pretty popular. i don't think you can think if it is the best, but i think it's been around for a long time.
#
# person beta:
# many cultures believe that the germanyphoridae of southern italy. it's pretty popular in the world.
#
# person alpha:
# that's incredible. i really enjoyed the taste of the ingredients. i like all the fresh produce that you can add.
#
# person beta:
# the word "pizza" was first recorded in the 10th century.
#
# person alpha:
# i was in the us in the usa news department of the world. i was just getting a job on my business.
#
# person beta:
# that's awesome. do you know the job management law?
#
# person beta:
# no i don't. i don't think i'll retire though. i am just a
# ==========
# 4,000 steps reached: saving model to //content/drive/MyDrive/Programming/ai-msgbot/GPT2-conversational-774M-Nov-25-2021_t-04
# 4,500 steps reached: generating sample texts.
# ==========
# . i think i would be surprised.
#
# person beta:
# yeah i want to try that too. i think i could do my best though. i use a wheelchair to make a lot of money.
#
# person alpha:
# i agree. there's so much more people, i think i could get some health care of it. if you don't take it, you can save me all the time.
#
# person beta:
# i think i can save you a better day. i buy certain types of online.
#
# person alpha:
# i agree, i know that i have a lot of free time. i'll have to look into your eyes and make it!
#
# person beta:
# i see. my brother also wants one!
#
# person beta:
# that's interesting. some people call it "goodness".
#
# person alpha:
# i work in a circus as a juggler.
#
# person beta:
# i love dogs. i love dogs! dogs. what kind of dog you had?
#
# person alpha:
# i actually have a mixed breed. i have a mixed breed but now i have my own dog to be labradt or let me let me let me tell
#
# person beta:
#
# ==========
# 5,000 steps reached: saving model to //content/drive/MyDrive/Programming/ai-msgbot/GPT2-conversational-774M-Nov-25-2021_t-04
# 6,000 steps reached: saving model to //content/drive/MyDrive/Programming/ai-msgbot/GPT2-conversational-774M-Nov-25-2021_t-04
# 6,000 steps reached: generating sample texts.
# ==========
#  was a lot of fun
#
# person alpha:
# i do not like the taste of the black holes. i know that pink is a pale red color named after the same name in the deep south.
#
# person beta:
# that is interesting. what do you think of the color yellow? yellow is odd.
#
# person alpha:
# i enjoy pink, especially white and pink. pink is my favorite shade of blue
#
# person beta:
# your blue clothing! i love the different shades also.
#
# person alpha:
# the beatles is such a great way to recognize all the plants and the art at the same time.
#
# person beta:
# do you prefer the rolling stones or do you prefer them to the british style?
#
# person alpha:
# not really, i prefer british style.
#
# person beta:
# same here. do you like the british style?
#
# person alpha:
# yeah, i like the black flag, black and silver and blue
#
# person beta:
# i prefer british, they are great british and it's weird that they are far from me :d
#
# person alpha:
# me too! it's also nice of the 3rd world
# ==========
# 7,000 steps reached: saving model to //content/drive/MyDrive/Programming/ai-msgbot/GPT2-conversational-774M-Nov-25-2021_t-04
# 7,500 steps reached: generating sample texts.
# ==========
# .
#
# person beta:
# is that a good choice?
#
# person alpha:
# i think it is! i have a guilty pleasure of balance.
#
# person beta:
# that's a great way to have! i wonder how long it takes to get to go to sleep?
#
# person alpha:
# i'm just not sure exactly, but it depends on the person for an average of time. i guess that's what they're saying. i just need to change.
#
# person beta:
# yeah, it's a concept. it's like a lot of exercise and a form of body language.
#
# person alpha:
# i think american eagle outfitters are known as a fostita bread or anything. they are just or fancy.
#
# person beta:
# oh i see! i had no idea they were first.
#
# person alpha:
# typically in 1977 they were made with some kind of tupacabra. they have a very distinct flavor. they also like to build any type of jeans.
#
# person beta:
# i am not familiar with the actual store i have heard the name of the ones you would like.
#
# person alpha:
# yeah they had a crazy name. they have a
# ==========
# 8,000 steps reached: saving model to //content/drive/MyDrive/Programming/ai-msgbot/GPT2-conversational-774M-Nov-25-2021_t-04
# 9,000 steps reached: saving model to //content/drive/MyDrive/Programming/ai-msgbot/GPT2-conversational-774M-Nov-25-2021_t-04
# 9,000 steps reached: generating sample texts.
# ==========
#  in the us.
#
# person alpha:
# have you ever been in a depressed before?
#
# person beta:
# depression is a state of low mood and aversion to activity
#
# person alpha:
# yes it was and it's very sad.
#
# person beta:
# yeah, the depressed mood is often rainy sometimes, both parties need to be a normal temporary reaction
#
# person alpha:
# there are so many single parent families in the us. i got my kitten from a few years ago.
#
# person beta:
# are you serious how it is a new disorder
#
# person alpha:
# yes, a single parent families is a parent.
#
# person beta:
# i am thankful for people like it! how long does the usually last?
#
# person alpha:
# some children to win the song, a legal guardian, and a child member from an emotional school
#
# person beta:
# that is impressive! does it usually go to school for that?
#
# person alpha:
# yes, and it usually occurs after raising an extended child
#
# person beta:
# that is a very good analogy! are you in a good school or in some areas,?
#
# person alpha:
# i'm on track and field!
# ==========
# 10,000 steps reached: saving model to //content/drive/MyDrive/Programming/ai-msgbot/GPT2-conversational-774M-Nov-25-2021_t-04
# 10,500 steps reached: generating sample texts.
# ==========
# .
#
# person alpha:
# that is true. i have heard the term.
#
# person beta:
# yes. the name was first developed in 1481 by a german god. i wonder if hans christian.
#
# person alpha:
# i really enjoy singing, do you?
#
# person beta:
# absolutely, i do. i really enjoy the sing, i used to sing when i was a kid.
#
# person alpha:
# wow! very fun. i've been all for it. i was thinking about getting my own musical instrument when i was younger.
#
# person beta:
# i'd go for a small time until it became popular for a quick. when i was younger, it was such a wonderful.
#
# person alpha:
# i'm sure you would like that there are a lot of singing. what album was it on?
#
# person beta:
# i think maybe i was a bit young. i remember a few of the songs that had the lowest in the voice. "what makes the band" that had the song on the radio down.
#
# person alpha:
# i love the beatles! i have an english rock band formed in 1960
#
# person beta:
# oh cool! i love
# ==========
# 11,000 steps reached: saving model to //content/drive/MyDrive/Programming/ai-msgbot/GPT2-conversational-774M-Nov-25-2021_t-04
# 12,000 steps reached: saving model to //content/drive/MyDrive/Programming/ai-msgbot/GPT2-conversational-774M-Nov-25-2021_t-04
# 12,000 steps reached: generating sample texts.
# ==========
# , and i am very curious, nothing that you've learned.
#
# person alpha:
# i love to play the piano. do you play?
#
# person beta:
# i wish i did but i never had any lessons on the beautiful acoustic stringed musical instrument
#
# person alpha:
# i love the guitar. do you play any instruments?
#
# person beta:
# i love guitar music myself.
#
# person alpha:
# i love the fretted instrument. i used to play it too. my son played it in high school. it's awesome how it was in school.
#
# person beta:
# that's awesome! i love listening to jazz. it's one of my favorite genres of music.
#
# person alpha:
# it's very loud, it's not too late in te fields and the different kinds of music.
#
# person beta:
# i agree. it's very soothing. it's also somewhat of a drinker and the way that they're used to make different sounds.
#
# person beta:
# yes, it's also different from the old english dictionary.
#
# person alpha:
# i love to swim. it's great exercise.
#
# person beta:
# it's very good for the joints compared to
# ==========
# 13,000 steps reached: saving model to //content/drive/MyDrive/Programming/ai-msgbot/GPT2-conversational-774M-Nov-25-2021_t-04
# 13,500 steps reached: generating sample texts.
# ==========
#
#
# person alpha:
# i love eating iced tea. it is so delicious.
#
# person beta:
# wow, i'm kind of tired. it's typically used for street or used as a minor drink.
#
# person alpha:
# do you like it?
#
# person beta:
# it's okay, i can't drink iced tea, although it is owned by it.
#
# person alpha:
# it is delicious. i mean i don't like it that much.
#
# person beta:
# i'm not sure, it's used as a tea drinking in the us.
#
# person alpha:
# i am allergic to it, but i'm allergic to it. i would hate to know much about it.
#
# person beta:
# it is a high risk, its used for low unemployment and physical benefits.
#
# person alpha:
# i love swimming, helps me keep a toned and fit body. six pack looks better than ever now!
#
# person beta:
# i like swimming too, only for recreation and exercise and sport. i cannot win at the sport, i am too slow
#
# person alpha:
# haha well even if it's only for recreation, it is an survival and safe way to
# ==========
# 14,000 steps reached: saving model to //content/drive/MyDrive/Programming/ai-msgbot/GPT2-conversational-774M-Nov-25-2021_t-04
# 15,000 steps reached: saving model to //content/drive/MyDrive/Programming/ai-msgbot/GPT2-conversational-774M-Nov-25-2021_t-04
# 15,000 steps reached: generating sample texts.
# ==========
#  in the us
#
# person beta:
# i'm sure it must be, especially since it is over 65 million and a worldwide.
#
# person alpha:
# i am planning my winter vacation, and am considering puerto rico - have you ever been there?
#
# person beta:
# i sure have, ive been to the capital here and pretty much all of san juan
#
# person alpha:
# i like to play video games and star craft is my favorite game.
#
# person beta:
# i have not ever played that game, but it is fun. i know it is a first released in 1995 for the xbox.
#
# person alpha:
# what are the types of game of the xbox?
#
# person beta:
# it's a playstation console that was released on may 12 2005.
#
# person alpha:
# wow, it must be very old in the xbox
#
# person beta:
# yes, but then a while to xbox one day.
#
# person alpha:
# i love to play video games and star craft is my favorite game.
#
# person beta:
# i have not ever played fortnite, but it sounds interesting.
#
# person alpha:
# oh yeah it is a
# ==========
# 16,000 steps reached: saving model to //content/drive/MyDrive/Programming/ai-msgbot/GPT2-conversational-774M-Nov-25-2021_t-04
# 16,500 steps reached: generating sample texts.
# ==========
# ,, that one's their most favorite teams
#
# person alpha:
# i did not know that. they have a pretty good team. their team, just so many teams.
#
# person beta:
# that's a great player. they don't have a great player. they just don't get a trophy based on the play or do they?
#
# person alpha:
# oh really, i like my team sport
#
# person beta:
# indeed i played at the world cup with a frisbee, inc., or owned by jess mcmahon in 1952!
#
# person alpha:
# i think i saw some really cool game play those on the internet. did you play the tony universe at christmas?
#
# person beta:
# that is so amazing! it was fun! i bought the original vipino brand, owned by ulysses s. grant in 2001 that is what was the best selling t-bone on the christian solar eclipse.
#
# person alpha:
# i have never seen the tampa!
#
# person beta:
# right? i haven't seen the tampa platform yet. the tampa bay in france and the solar eclipse.
#
# person alpha:
# i think i have heard
# ==========
# 17,000 steps reached: saving model to //content/drive/MyDrive/Programming/ai-msgbot/GPT2-conversational-774M-Nov-25-2021_t-04
# 18,000 steps reached: saving model to //content/drive/MyDrive/Programming/ai-msgbot/GPT2-conversational-774M-Nov-25-2021_t-04
# 18,000 steps reached: generating sample texts.
# ==========
#
#
# person alpha:
# i love to watch the sunset on the beach.
#
# person beta:
# that sounds like a really fun day at the beach. i'm so scared of people.
#
# person beta:
# yes i would love to surf in the ocean.
#
# person alpha:
# i was so scared of the same. i have never watched it but i hear that good it is a better seller of the movie!
#
# person beta:
# i love all the movies. it's like a christian old war reenactment, which is a very old movie.
#
# person alpha:
# it sure did. i watched a lot of action movies with my kids. it was pretty cool.
#
# person beta:
# yes, martin with a lot of emmy, and a lot of action scenes are made for many years, but they couldn't be inaccurate.
#
# person alpha:
# i like to take drives in the country side off my blue.
#
# person beta:
# that sounds exciting. blue's weird because the sky is higher. blue is an optical effect named rayleigh scattering
#
# person alpha:
# i've never heard of that. what does it involve?
#
# person beta:
# it
# ==========
# 19,000 steps reached: saving model to //content/drive/MyDrive/Programming/ai-msgbot/GPT2-conversational-774M-Nov-25-2021_t-04
# 19,500 steps reached: generating sample texts.
# ==========
# , or using just one person to get the symptoms of its body when it's negatively a major pain. it gets such symptoms of understanding.
#
# person alpha:
# i love dogs. do you know much about boxers?
#
# person beta:
# not too much, i do know what they vary in shape, size and colour colors.
#
# person alpha:
# wow. i like to know. what about boxers does it come from?
#
# person beta:
# the colors vary from white to red, yellow, and orange.
#
# person alpha:
# i love eating it all.
#
# person beta:
# me too, it is delicious. it is made with raw seafood, brown, and sometimes combined with eggs, molasses. it is made of calcium, added, the ingredients go hungry.
#
# person alpha:
# i have always been interested in hiking, what about you?
#
# person beta:
# yes, it is an important meal here in the countryside because it is breaking the water from your body of water for cheap.
#
# person alpha:
# that is true, it is important to do not have a good understanding of the unhealthy animals.
#
# person beta:
# yes, it is. especially if it
# ==========
# 20,000 steps reached: saving model to //content/drive/MyDrive/Programming/ai-msgbot/GPT2-conversational-774M-Nov-25-2021_t-04
# 21,000 steps reached: saving model to //content/drive/MyDrive/Programming/ai-msgbot/GPT2-conversational-774M-Nov-25-2021_t-04
# 21,000 steps reached: generating sample texts.
# ==========
# .
#
# person beta:
# oh wow, gosh, that's a pretty good idea! i've only been to virginia, so i've been to virginia, but i haven't gone with the chance.
#
# person alpha:
# the blue ridge parkway is one of my favorite places to hike.
#
# person beta:
# where is the blue ridge?
#
# person alpha:
# it is the most beautiful locations in virginia, and it is interesting to do the most part.
#
# person beta:
# i see, where is it most populous?
#
# person alpha:
# it is the most populous in virginia. there are the largest.
#
# person beta:
# what is virginia?
#
# person beta:
# the blue ridge parkway is a national parkway and virginia
#
# person alpha:
# i can't wait to go to virginia! i've only been to virginia before and it was gorgeous!
#
# person beta:
# i have never been to virginia before, but would love to. i have been to virginia once for a long time.
#
# person alpha:
# i have not been. i think the atmosphere has a lot of history like is apparently so the idea
# ==========
# 22,000 steps reached: saving model to //content/drive/MyDrive/Programming/ai-msgbot/GPT2-conversational-774M-Nov-25-2021_t-04
# 22,500 steps reached: generating sample texts.
# ==========
#  of the cat.
#
# person alpha:
# a cat is an animal shelter?
#
# person beta:
# yes, they are often called pet. not sure about cats, invertebrates are cared for by profession.
#
# person alpha:
# i prefer dogs over cats. how about dogs?
#
# person beta:
# i do a cat, but many dogs have specific personalities with humans has led dogs to their own opinion. so is your dog friendly?
#
# person alpha:
# i love pecan pie. pecan pie is obviously a pie of pecan nuts.
#
# person beta:
# i've never been able to get into pecan pie, where pecan pie originated?
#
# person alpha:
# it was quite popular down in the southern portion of the us.
#
# person beta:
# i love pecan pie. do you know anything about pecan pie?
#
# person beta:
#  pecan pie is my favorite pie. thanks for pecan pie.
#
# person alpha:
# hey. i love to sing. well, more accurately, i used to. it requires too much time and consistent practice.
#
# person beta:
# i wish i could sing so i can lessons on a slice of the piano,
# ==========
# 23,000 steps reached: saving model to //content/drive/MyDrive/Programming/ai-msgbot/GPT2-conversational-774M-Nov-25-2021_t-04
# 24,000 steps reached: saving model to //content/drive/MyDrive/Programming/ai-msgbot/GPT2-conversational-774M-Nov-25-2021_t-04
# 24,000 steps reached: generating sample texts.
# ==========
# .
#
# person alpha:
# hi, do you like french fries?
#
# person beta:
# i love french fries. they are one of my favorite foods. it's called french fries.
#
# person alpha:
# i like to order fries in my spare time.
#
# person beta:
# i do as well! i like to load my steaks in the morning.
#
# person alpha:
# i like to do beadwork for fun!
#
# person beta:
# thats cool! they perform in large variety of plants, including blood and synthetic plants.
#
# person alpha:
# when did you learn them?
#
# person beta:
# oh yeah! i bet they were difficult as stringed at all.
#
# person alpha:
# i really like the color blue is a solid color that can be topped with bright blue or red.
#
# person beta:
# many of the shades of blue are actually my favorite - a rose of green.
#
# person alpha:
# that is good - i would love to know more about the color blue
#
# person beta:
# do you know what blue is made of?
#
# person alpha:
# i think it's a shade of blue - a rose of a ocean and then have
# ==========
# 25,000 steps reached: saving model to //content/drive/MyDrive/Programming/ai-msgbot/GPT2-conversational-774M-Nov-25-2021_t-04
# 25,500 steps reached: generating sample texts.
# ==========
#  at the public theater. it is a big art society that works in.
#
# person alpha:
# i love the color blue!
#
# person beta:
# blue is my favorite primary and a primary colour theory in painting and traditional colour theory
#
# person alpha:
# what other primary colors are blue?
#
# person beta:
# i like blue, but my favorite is green
#
# person alpha:
# that's a great favorite. what are your favorite primary colors?
#
# person beta:
# i love how their eyes are blue because of another optical effect called rayleigh scattering.
#
# person alpha:
# i am so sick of these allergies! allergies include a number of conditions caused by hypersensitivity of the immune system.
#
# person beta:
# allergies are serious health issues, what is the most common causes that immune system?
#
# person alpha:
# i am allergic to a lot of allergies and have pollen allergy and also some food allergies.
#
# person beta:
# wow, which food and what does it do to your body
#
# person beta:
# i am allergic to milk and peanuts cause itching and peanuts cause itching and severe swelling.
#
# person alpha:
# i love ice cream! my favorite is kind of ice cream
# ==========
# 26,000 steps reached: saving model to //content/drive/MyDrive/Programming/ai-msgbot/GPT2-conversational-774M-Nov-25-2021_t-04
# 27,000 steps reached: saving model to //content/drive/MyDrive/Programming/ai-msgbot/GPT2-conversational-774M-Nov-25-2021_t-04
# 27,000 steps reached: generating sample texts.
# ==========
# , and i like to eat them
#
# person alpha:
# i really like to watch basketball
#
# person beta:
# basketball is a limited contact sport
#
# person alpha:
# is it?
#
# person beta:
# basketball is very91 and internationally doesn't have the health benefits
#
# person alpha:
# is it? i think it would be because it's also a mental healthiest?
#
# person beta:
# no, unlike the most important point in the us for the most part. the symptoms can be broken into place to improve the sport.
#
# person alpha:
# that's true. i guess i'd want to get back into more major sports like what sports are the best?
#
# person beta:
# if each player had the horse the other ones were the bat. the only type 1 was an nhl which was a thing.
#
# person alpha:
# i like to dance do you?
#
# person beta:
# yes! i'm not a very self-propulsion of dancing. i love to dance and i like to do some classical dancing.
#
# person alpha:
# i think i need to learn how to use a psychologist.
#
# person beta:
# i think that's awesome. you need to have
# ==========
# 28,000 steps reached: saving model to //content/drive/MyDrive/Programming/ai-msgbot/GPT2-conversational-774M-Nov-25-2021_t-04
# 28,500 steps reached: generating sample texts.
# ==========
# .
#
# person beta:
# yeah, i don't think i could just give it a go.
#
# person alpha:
# you know, some people love to eat animal shelters even if they're kind of a new owner!
#
# person beta:
# that's true. i have a few and am into the street person too.
#
# person beta:
# oh nice! i love working with my hands. it can be distinguished from legends and political.
#
# person alpha:
# have you ever seen an armadillo? they are mammals that have leathery armour shells?
#
# person beta:
# oh yeah those invasive things are all over the place where i live!
#
# person alpha:
# armadillos are from the americas. they're a variety of places in south america.
#
# person beta:
# oh i know, i always wanted to be an armadillo
#
# person alpha:
# they're invasive, they're a number of conditions. many species are included in the "parmadillo" due to their fast tempos.
#
# person beta:
# armadillos are kind of like leathery armour
#
# person beta:
# that's interesting. they're kind of like rodents for
# ==========
# 29,000 steps reached: saving model to //content/drive/MyDrive/Programming/ai-msgbot/GPT2-conversational-774M-Nov-25-2021_t-04
# 30,000 steps reached: saving model to //content/drive/MyDrive/Programming/ai-msgbot/GPT2-conversational-774M-Nov-25-2021_t-04
# 30,000 steps reached: generating sample texts.
# ==========
# , and it is so cool to have a nice day!
#
# person alpha:
# haha! i really like the small quaint feeling.
#
# person beta:
# i like the cola bottle shapes, but i don't know much about them.
#
# person alpha:
# oh yes, their sole frozen was the chanel brand. they are at the front of their headquarters.
#
# person beta:
# ahhh! what's your favorite brand to buy?
#
# person alpha:
# i like the smoothes and the chanel brand of leon. it was started by louis chanel.
#
# person beta:
# i wonder if they were as old as their own brands.
#
# person beta:
# i have no idea. they were first founded way back in 1961.
#
# person alpha:
# have you ever been to or volunteeredance of the united states?
#
# person beta:
# i have not. but i want to go.
#
# person alpha:
# i have been to many different places. most recently to chile. have you ever been out of the country?
#
# person beta:
# i have! i love it!
#
# person alpha:
# i love it because it is
# ==========
# 31,000 steps reached: saving model to //content/drive/MyDrive/Programming/ai-msgbot/GPT2-conversational-774M-Nov-25-2021_t-04
# 31,500 steps reached: generating sample texts.
# ==========
#  of the old english speaking.
#
# person beta:
# oh that is pretty interesting! i think my favorite of all the colors are blue and some of jagger. what are some of yours?
#
# person alpha:
# you might have heard of these is i like. i think it is because of the blue and vibrant.
#
# person beta:
# it is crazy that violet is so calming. i know it's funny that the blue in the human to be behind an area!
#
# person alpha:
# i love to party.
#
# person beta:
# parties typically feature food and drinks. what are some of your favorites?
#
# person alpha:
# cheese and crackers are often paired with wine. do you enjoy wine?
#
# person beta:
# oh yes, wine are good, but i really like wine and so much.
#
# person beta:
# i agree, i like the spirit of the wincheia, where it's at.
#
# person alpha:
# i love coffee!
#
# person beta:
# me too! do you have any favorite espresso food?
#
# person alpha:
# no,i don't. i dislike the texture in the mouth, it feels as though i'm drinking worms or
# ==========
# 32,000 steps reached: saving model to //content/drive/MyDrive/Programming/ai-msgbot/GPT2-conversational-774M-Nov-25-2021_t-04
# 33,000 steps reached: saving model to //content/drive/MyDrive/Programming/ai-msgbot/GPT2-conversational-774M-Nov-25-2021_t-04
# 33,000 steps reached: generating sample texts.
# ==========
#  is an italian cuisine. i like his style.
#
# person alpha:
# so do i! i love to eat all the things!
#
# person beta:
# me too! and boiled eggs are just so delicious!
#
# person alpha:
# yeah, i don't eat any meat so that's why i love some pork.
#
# person beta:
# i cant eat any fish and just eat any animal and vegetables on a plate! since i can't live without milk.
#
# person alpha:
# i don't but some of my family love to eat is cheesecake. we eat lots of bacon.
#
# person beta:
# oh yeah and don't get the term "pizza-pca does get to cook and then where it's just a burger!
#
# person alpha:
# that's a tough way to make a large breakfast, you can never change it! lol i have the older lanned and most of it's disappointing.
#
# person beta:
# it is a great poet. and it's believed to be the most powerful thing in the world.
#
# person alpha:
# i have a dog that can be the best for me and i do not have a chihuahua!
#
# person beta
# ==========
# 34,000 steps reached: saving model to //content/drive/MyDrive/Programming/ai-msgbot/GPT2-conversational-774M-Nov-25-2021_t-04
# 34,500 steps reached: generating sample texts.
# ==========
#  of the number of years.
#
# person alpha:
# i am a big fan of the ford motor company. i currently drive a ford f150. do you also like them?
#
# person beta:
# absolutely. my father used to work in houston. it where they work through headquartered in houston. indiana. where ford, we headquartered. i love them because they love their cars, but they make great vehicles.
#
# person alpha:
# wow, that's too cool. do you know anything cool about the honda brand?
#
# person beta:
# i drive a honda. they make really good cars and motorcycles. honda are the world's largest motorcycle, so a lot of a good example!
#
# person alpha:
# i see. why do you think honda are the second-largest japanese auto manufacturer
#
# person beta:
# i'm not familiar with their honda fit. i actually didn't do that they are the 8th largest japanese automobile. sorry.
#
# person alpha:
# i am not sure. as of 2015 they are the 8th largest, right?
#
# person beta:
# i think we are. noveac's income is japanese
# ==========
# 35,000 steps reached: saving model to //content/drive/MyDrive/Programming/ai-msgbot/GPT2-conversational-774M-Nov-25-2021_t-04
# 36,000 steps reached: saving model to //content/drive/MyDrive/Programming/ai-msgbot/GPT2-conversational-774M-Nov-25-2021_t-04
# 36,000 steps reached: generating sample texts.
# ==========
#
#
# person alpha:
# i love the color blue, i think it is the best shade of color
#
# person beta:
# i love purple. even though i like it more than just purple. purple is my favorite color.
#
# person alpha:
# i'm obsessed with the color purple.
#
# person beta:
# purple is a color that is usually associated with color, purple is my favorite. do you like purple?
#
# person alpha:
# i think purple is such a lovely color! when purple is similar to violet, purple is associated with purple.
#
# person beta:
# really? it's such a pretty color lol. i don't know it's the same with purple.
#
# person alpha:
# it is very nice and very nice looking too! i don't know that the different shades like purple is the color purple.
#
# person beta:
# purple actually vary in between violet and green on the spectrum of visible light.
#
# person alpha:
# i love visiting florida. it has the longest coastline in the us
#
# person beta:
# i have always wanted to go there, are the beaches fun?
#
# person beta:
# they are. and the weather is great. it varies from
# ==========
# 37,000 steps reached: saving model to //content/drive/MyDrive/Programming/ai-msgbot/GPT2-conversational-774M-Nov-25-2021_t-04
# 37,500 steps reached: generating sample texts.
# ==========
# .
#
# person beta:
# have you ever heard of the band ween? uts an alternative rock back
#
# person beta:
# no i haven't. though their record number together with them.
#
# person alpha:
# i have been listening to a lot of bruno mars lately, i just love his style of music, do you know about him?
#
# person beta:
# i love his real name is peter gene hernandez
#
# person alpha:
# oh really, hes not much older than me! i knew he was young, do you know where he grew up?
#
# person beta:
# he was born and raised in honolulu, hawaii, by a family of musicians
#
# person alpha:
# neato, thats what he got his most life heard it, i know a lot about his life, do you know?
#
# person beta:
# i do not, but he was born in hawaii, by a family of musicians
#
# person alpha:
# oh, thats interesting, he was younger that way, thats why i never knew his father was a young age! hes amazing, do you know much about his background positions?
#
# person beta:
# he was born on 53, his
# ==========
# 38,000 steps reached: saving model to //content/drive/MyDrive/Programming/ai-msgbot/GPT2-conversational-774M-Nov-25-2021_t-04
# 39,000 steps reached: saving model to //content/drive/MyDrive/Programming/ai-msgbot/GPT2-conversational-774M-Nov-25-2021_t-04
# 39,000 steps reached: generating sample texts.
# ==========
#  with the name of the british greek version of the british dictionary.
#
# person beta:
# are the house cats pretty accurate? i wonder when the siamese sauce got really popular.
#
# person alpha:
# i heard that the cheeseburgers are the cheeseburgers and the only thing burger king's toppings.
#
# person beta:
# i have never heard of a cheeseburger, so i would love to visit all the burgers.
#
# person beta:
# oh i know! the cheeseburger is really popular in.
#
# person alpha:
# hey, i love eating hamburgers they are the best, i love them
#
# person beta:
# yeah, they give a great flavor. pasting cheese is a push.
#
# person alpha:
# yes i love cheese! you know i love the patty brand well! you will like the patty grill pan fried.
#
# person beta:
# i've never heard of that brand. do you have a burger? i think it's been heard of that.
#
# person beta:
# oh, you have it? i love the flame with cheese, you know. they have a cheeseburger.
#
# person alpha:
# ==========
# 40,000 steps reached: saving model to //content/drive/MyDrive/Programming/ai-msgbot/GPT2-conversational-774M-Nov-25-2021_t-04
# 40,500 steps reached: generating sample texts.
# ==========
#  to get together with it's time.
#
# person beta:
# i love my blonde hair!
#
# person beta:
# mine too! i just recently found out that the ancient mention of the beard - it's an evolutionary trait from the battle to that.
#
# person alpha:
# i really like skateboarding, have you ever tried this olympic sport?
#
# person beta:
# i have not, it seems dangerous to me, is it safer than it seems?
#
# person alpha:
# there are definitely some dangers associated, but proper equipment can help manage that. the sport was inspired by skateboarding and surfing.
#
# person beta:
# is it any safer than those sports? i have been skateboarding
#
# person alpha:
# i don't think it's any safer than those sports. modern snowboarding began in 1965.
#
# person beta:
# what is the modern snowboarding method?
#
# person alpha:
# i'm not sure, i've only seen pictures research on tv. i find it interesting that the modern olympic sport was developed based on the decline based on the decline.
#
# person beta:
# what else can you tell me about skateboarding?
#
# person beta:
# i don't know
# ==========
# 41,000 steps reached: saving model to //content/drive/MyDrive/Programming/ai-msgbot/GPT2-conversational-774M-Nov-25-2021_t-04
# 42,000 steps reached: saving model to //content/drive/MyDrive/Programming/ai-msgbot/GPT2-conversational-774M-Nov-25-2021_t-04
# 42,000 steps reached: generating sample texts.
# ==========
#
#
# person beta:
# yeah, i think my favorite type of truck is the most strange you have ever been in existence.
#
# person beta:
# the transport itself was previously divided into two types, called, "faster",", and "calf." i think i have to consume one on rolling.
#
# person alpha:
# i used to work at a feed store too! i worked at a place that worked at a place that worked in the bank.
#
# person beta:
# thats a lot of people. the job always worked very large in the bank
#
# person alpha:
# i agree. factory work in a factory, sometimes in sales of exchange relationships to ensure all day.
#
# person beta:
# i know mine worked at a station in the bank. how long it is now?
#
# person beta:
# ive really been involved in the center for about 21, but some overall influential people have been directly working. some people think that they are no more popular too.
#
# person alpha:
# i love to go snowboarding.
#
# person beta:
# skateboarding is fun.
#
# person alpha:
# what are the most common tricks?
#
# person beta:
# i have a lot of skate
# ==========
# 43,000 steps reached: saving model to //content/drive/MyDrive/Programming/ai-msgbot/GPT2-conversational-774M-Nov-25-2021_t-04
# 43,500 steps reached: generating sample texts.
# ==========
#  on the internet.
#
# person beta:
# oh wow, they are amazing, its the second longest internet guinea, idk why you get a second week for picnics!
#
# person alpha:
# i love chocolate rocky road ice cream
#
# person beta:
# i love chocolate chip ice cream
#
# person alpha:
# i love chocolate rocky road ice cream
#
# person beta:
# i love chocolate chip ice cream
#
# person alpha:
# i love chocolate chip ice cream
#
# person beta:
# i love chocolate chip ice cream
#
# person alpha:
# i love chocolate chip ice cream
#
# person beta:
# i love ice cream
#
# person alpha:
# it is delicious. i love the chocolate chip in the summer to ice cream to pull out on chocolate ice cream.
#
# person beta:
# i love chocolate chip ice cream
#
# person alpha:
# i love ice cream, it always cheers me up. i wish my favorite ice cream flavor is mint chocolate chip.
#
# person beta:
# i like ice cream too! my favorite is ice cream
#
# person beta:
# oh yeah it. i like gelato, i like frozen custard but i pretty much just in the ice cream.
#
# person alpha
# ==========
# 44,000 steps reached: saving model to //content/drive/MyDrive/Programming/ai-msgbot/GPT2-conversational-774M-Nov-25-2021_t-04
# 45,000 steps reached: saving model to //content/drive/MyDrive/Programming/ai-msgbot/GPT2-conversational-774M-Nov-25-2021_t-04
# 45,000 steps reached: generating sample texts.
# ==========
#  and so is the process of creating and gathering.
#
# person beta:
# what's the largest hobby of the show? the surgery of the simpsons, which is similar to the simpsons
#
# person alpha:
# i love dogs and i have three dogs!
#
# person beta:
# dogs are great. they're superland and loveable and they're such good natured dogs.
#
# person alpha:
# i love animals
#
# person beta:
# wow, really. i got my dog from a shelter too. she's adorable, but a handful sometimes.
#
# person alpha:
# they're awesome animals, especially considering their name is mans best friend. i wonder if they're because they're known to be strong and not as pets.
#
# person beta:
# they're so cute. you have welshank their pets, and they have a good sense of heights and their good temper and they're good at that. do you have pets?
#
# person alpha:
# i have a heel but he's the best dog. they're cute and loyal, their great pets.
#
# person beta:
# yes i agree! dogs are good animals, and their relation to the gray wolf. do you have a favorite breed?
#
# ==========
# 46,000 steps reached: saving model to //content/drive/MyDrive/Programming/ai-msgbot/GPT2-conversational-774M-Nov-25-2021_t-04
# 46,500 steps reached: generating sample texts.
# ==========
# " plant.
#
# person alpha:
# yeah i'm sure i've heard of them. i've seen people grow them in a flash. is that a big reason?
#
# person beta:
# yes its kinda large and has it imported from flower pound in front of the flower heads and one side and is usually called a white flower.
#
# person alpha:
# i love chocolate. its a typically sweet and brown food in color
#
# person beta:
# whati find your job usually?
#
# person alpha:
# basically! i love the fact that is more and more religious debate.
#
# person beta:
# never heard of what you're saying. what about keeping a cat a dog?
#
# person alpha:
# i would say that i have to say my favorite beren a dog at daniels. beagles have been around a while.
#
# person beta:
# what kind of dog do you have?
#
# person beta:
# i have a dingo its a long time! i learned about that i had a dog that was deaf and an diberian.
#
# person alpha:
# hello, i love the intense genre of rock music called heavy metal. do you?
#
# person beta:
# i do
# ==========
# 47,000 steps reached: saving model to //content/drive/MyDrive/Programming/ai-msgbot/GPT2-conversational-774M-Nov-25-2021_t-04
# 48,000 steps reached: saving model to //content/drive/MyDrive/Programming/ai-msgbot/GPT2-conversational-774M-Nov-25-2021_t-04
# 48,000 steps reached: generating sample texts.
# ==========
#  is a lot less than in the shower, although in my daughters
#
# person alpha:
# i love dogs. huskies are my sled dogs in sled dogs
#
# person beta:
# i've never had one, are they used for, or considering very long?
#
# person alpha:
# they are also used to pulling the pulling of dead and the under is they are selectively bred for
#
# person beta:
# yeah, i don't really need to get in the hospital, i need to find out some soon too. i wonder if they get too injured.
#
# person beta:
# i don't know if they were just formal, but it is sad that they are a little pain at hunting
#
# person alpha:
# i love steak!
#
# person beta:
# yeah do you know the lot about them
#
# person beta:
# well, many are quite a few meat and usually consumed. i usually think some beef is too beef for beef.
#
# person alpha:
# i have heard of him, but i don't know much about him generally
#
# person beta:
# he was born and raised in honolulu, germany.
#
# person alpha:
# do you think he would like to eat a beef?
#
#
# ==========
# 49,000 steps reached: saving model to //content/drive/MyDrive/Programming/ai-msgbot/GPT2-conversational-774M-Nov-25-2021_t-04
# 49,500 steps reached: generating sample texts.
# ==========
# "
#
# person alpha:
# yeah i'm so glad to have to pick up beer. it's usually served with pickled ginger, sausage and later on the right side so i'm not a fan.
#
# person beta:
# i'm not a fan. i'm just soft the way it's always brag, but i was wondering if your hair is too hot!
#
# person alpha:
# mine is too hot! i don't know why we often see a "steak" just stick to a point of my eye. i wonder what everyone tastes in my chest?
#
# person beta:
# i think thats why...but i'd be a good thing! i don't know! lol it takes "budutut in the newss" though.
#
# person alpha:
# i am a night owl's most beautiful night owl, i love staying up late!
#
# person beta:
# i've always stayed up in the morning. is there some time why, and there have been to bed?
#
# person alpha:
# no, but i am just wondering about my local drama. what's your favorite part?
#
# person beta:
# me too i feel it was just the body getting on my circadian rhythm. i
# ==========
# 50,000 steps reached: saving model to //content/drive/MyDrive/Programming/ai-msgbot/GPT2-conversational-774M-Nov-25-2021_t-04
# 51,000 steps reached: saving model to //content/drive/MyDrive/Programming/ai-msgbot/GPT2-conversational-774M-Nov-25-2021_t-04
# 51,000 steps reached: generating sample texts.
# ==========
#  and the york times.
#
# person beta:
# i have never seen those sound so in the u.k. what is it exactly?
#
# person alpha:
# there are so many great artists that have been found in the usa andy, with nearly one single of nearly every year.
#
# person beta:
# i have only been to a few as well. as well as a kid, i always thought there was to a lot, but there wasn't the best representation.
#
# person beta:
# hmm that sounds like an interesting fact, but anything interesting?
#
# person beta:
# i think the term is a bit like a synlado group. that means to the nation's capital, but that it's less comars than that.
#
# person alpha:
# i love steak. i wonder how they are made
#
# person beta:
# steak is meat sliced across the muscles including bone
#
# person alpha:
# oh that nice, it means that every eatable animal can be a potential steak?
#
# person beta:
# yes that is true.exceptions is meat sliced parallel to the fibres
#
# person alpha:
# ok nice, it will be so funny to see horse steak
#
# person
# ==========
# 52,000 steps reached: saving model to //content/drive/MyDrive/Programming/ai-msgbot/GPT2-conversational-774M-Nov-25-2021_t-04
# 52,500 steps reached: generating sample texts.
# ==========
#  by the red light 2.
#
# person beta:
# i was too young i had to get a later club haha, the color was nice though lol.
#
# person alpha:
# at first it could be, "blue" red, yellow blue could be more unique.
#
# person beta:
# that's my favorite type of color! what other colors are the red?
#
# person beta:
# well, it's a primary color. it's a primary color of colors and the color wheel.
#
# person alpha:
# i have a pug. i think i have a pug. do you own anypugs?
#
# person beta:
# i have three dogs! i have a pug. we have the the standard pugly and miniature poodle.
#
# person alpha:
# yes, the standard pug is a small sized breed. where do you like poodles come from?
#
# person beta:
# many years i have poodles. it is made from a type of cattle dogs.
#
# person alpha:
# what kind of specie! what other kinds of fillings are there?
#
# person beta:
# there is actually the pembroke welsh corgi corgi. it
# ==========
# 53,000 steps reached: saving model to //content/drive/MyDrive/Programming/ai-msgbot/GPT2-conversational-774M-Nov-25-2021_t-04
# 54,000 steps reached: saving model to //content/drive/MyDrive/Programming/ai-msgbot/GPT2-conversational-774M-Nov-25-2021_t-04
# 54,000 steps reached: generating sample texts.
# ==========
# .
#
# person alpha:
# i really love jim carrey, such an awesome actor!
#
# person beta:
# i know! his muscles are awesome! must forever be indebted to that!
#
# person alpha:
# yeah he was such a classic.
#
# person beta:
# what are your favorite movies of his?
#
# person alpha:
# i think dumb & dumber, liar liar and batman forever was some of jim carrey's best movies!
#
# person beta:
# i agree! he was really cute and a man of the 80s. back in the day it was hot & dry.
#
# person alpha:
# yeah he was a little guy that some nintendo was grossed out of the eight running increases the feeling of all of his nintendo games.
#
# person beta:
# i don't like that album.
#
# person alpha:
# not at all of it.
#
# person beta:
# i grew up listening to a family members in san jonesia.
#
# person alpha:
# i used to be an elementary school teacher. there are over 92 thousand elementary schools in the us
#
# person beta:
# that is a ton of schools, teaching would be a rewarding job, do
# ==========
# 55,000 steps reached: saving model to //content/drive/MyDrive/Programming/ai-msgbot/GPT2-conversational-774M-Nov-25-2021_t-04
# 55,500 steps reached: generating sample texts.
# ==========
# , and definitely being outside the country.
#
# person alpha:
# i love to eat chicken... especially fried chicken.
#
# person beta:
# chicken is one of my favorite meats as well. it's so versatile because you can eat almost daily.
#
# person alpha:
# i've never had soft drinks but it always tastes good. do you like chicken?
#
# person beta:
# i like it. it is one of the most common meats in the world. and very healthy!
#
# person alpha:
# i've always tried the chicken, but i'm sure that to me. i would love a good breakfast
#
# person beta:
# it is so great and so versatile and so versatile because it can be pretty much a lot of different foods, and some type of content.
#
# person alpha:
# i am very much depressed i feel guilty but sometimes i get anxiety about the pain.
#
# person beta:
# i love painters, too. i like how the lumbar and thingsk b/c sometimes.
#
# person alpha:
# have you ever tried skateboarding?
#
# person beta:
# i've never tried it, but i do to it, to fun! it looks fun, though i might get
# ==========
# 56,000 steps reached: saving model to //content/drive/MyDrive/Programming/ai-msgbot/GPT2-conversational-774M-Nov-25-2021_t-04
# 57,000 steps reached: saving model to //content/drive/MyDrive/Programming/ai-msgbot/GPT2-conversational-774M-Nov-25-2021_t-04
# 57,000 steps reached: generating sample texts.
# ==========
# .
#
# person alpha:
# hello, have you ever been to new york city?
#
# person beta:
# no, but i've read a bit about the city.
#
# person alpha:
# do you know, it's new york city?
#
# person beta:
# no, but i'm a fan, lol! have you heard much about the city?
#
# person alpha:
# not really, but i know they have a pretty nice city!
#
# person beta:
# yes, and it's a cultural, finantial, and media capers, and the statue of liberty!
#
# person alpha:
# i wonder sometimes if i am being a good parent to my daughters.
#
# person beta:
# i wonder the same thing too?
#
# person alpha:
# i'm not totally sure, but i think there's a lot less formal one. my family isleive.
#
# person beta:
# i'm not very big into cross-country, but i know she's very intergic crossword, sporty, and skiing!
#
# person alpha:
# wow that's very interesting. do you know she is referred to as ems?
#
# person beta:
# yes she's definitely
# ==========
# 58,000 steps reached: saving model to //content/drive/MyDrive/Programming/ai-msgbot/GPT2-conversational-774M-Nov-25-2021_t-04
# 58,500 steps reached: generating sample texts.
# ==========
# .
#
# person alpha:
# i would be terrified if i was held hostage.
#
# person beta:
# being seized by a criminal abductor is so terrifying! i always keep my gun in my nightstand just in case
#
# person alpha:
# really?i don't, i wouldn't know how to use it anyway. of course in the movies hostage situations can be entertaining, i guess.
#
# person beta:
# i go not a real harm. i was a little girl. what ariel would you teach him to her?
#
# person alpha:
# i never thought he would call him ahs -- he was raised in which is librarian and he would take space refer to the outside world
#
# person beta:
# thats awesome! i thought he would have been a role in the us! how much does he cost these days.
#
# person alpha:
# he sold a complete number one in canada
#
# person beta:
# i have heard that he has sold 10 world, but not sure how much, he is famous!
#
# person beta:
# yes i knew that when he passed away, i was born in 1975
#
# person alpha:
# i have a cat. he is small and kept indoors. also
# ==========
# 59,000 steps reached: saving model to //content/drive/MyDrive/Programming/ai-msgbot/GPT2-conversational-774M-Nov-25-2021_t-04

# %%
save_path = join(base_dir, 
                     "FINAL-GPT2-conv-{sz}-{dt}".format(sz=model_size,
                                                        dt=get_timestamp(),
                                                        )
                     )

# %%
import os
os.makedirs(save_path, exist_ok=True)
ai.save(save_path)

print(f'saved! {get_timestamp()}')

# %% [markdown]
# ---

# %% [markdown]
# ## Use a Trained Model for Generation
#
# If you already had a trained model from this notebook, running the next cell will copy the `pytorch_model.bin` and the `config.json`file from the specified folder in Google Drive into the Colaboratory VM. (If no `from_folder` is specified, it assumes the two files are located at the root level of your Google Drive)

# %%
# !nvidia-smi

# %%
mount_gdrive()

# %%
# best model thus far @ 1.3B parameters and tuned for 50k steps
# from_folder = "/content/drive/MyDrive/Programming/AI_peter/GPT-Neo-1B-V1"

from_folder = save_path

if len(from_folder) > 2:

    for file in ["pytorch_model.bin", "config.json"]:
        if from_folder:
            copy_file_from_gdrive(file, from_folder)
        else:
            copy_file_from_gdrive(file)

    ai = aitextgen(model_folder=from_folder, to_gpu=True)
else:
    ai = aitextgen(model_folder=".", to_gpu=True)

# %% [markdown]
# ### Generate Text

# %% [markdown]
# `generate()` without any parameters generates a single text from the loaded model to the console.

# %%
ai.generate(n=3, max_length=256, 
            temperature=1.0, top_p=0.9)

# %%
ai.generate(prompt="these days, it always seems like ", temperature=1,
            min_length=10, batch_size =20)

# %% [markdown]
# If you're creating an API based on your model and need to pass the generated text elsewhere, you can do `text = ai.generate_one()`
#
# You can also pass in a `prompt` to the generate function to force the text to start with a given character sequence and generate text from there (good if you add an indicator when the text starts).
#
# You can also generate multiple texts at a time by specifing `n`. You can pass a `batch_size` to generate multiple samples in parallel, giving a massive speedup (in Colaboratory, set a maximum of 50 for `batch_size` to avoid going OOM).
#
# Other optional-but-helpful parameters for `ai.generate()` and friends:
#
# *  **`min length`**: The minimum length of the generated text: if the text is shorter than this value after cleanup, aitextgen will generate another one.
# *  **`max_length`**: Number of tokens to generate (default 256, you can generate up to 1024 tokens with GPT-2 and 2048 with GPT Neo)
# * **`temperature`**: The higher the temperature, the crazier the text (default 0.7, recommended to keep between 0.7 and 1.0)
# * **`top_k`**: Limits the generated guesses to the top *k* guesses (default 0 which disables the behavior; if the generated output is super crazy, you may want to set `top_k=40`)
# * **`top_p`**: Nucleus sampling: limits the generated guesses to a cumulative probability. (gets good results on a dataset with `top_p=0.9`)

# %%
ai.generate(
    n=3, batch_size=25, prompt="i just", max_length=256, 
    temperature=1.0, top_p=0.9
)

# %% [markdown]
# For bulk generation, you can generate a large amount of texts to a file and sort out the samples locally on your computer. The next cell will generate `num_files` files, each with `n` texts and whatever other parameters you would pass to `generate()`. The files can then be downloaded from the Files sidebar!
#
# You can rerun the cells as many times as you want for even more generated texts!

# %%
save_loc = join(base_dir, "generated_text_out")

os.makedirs(save_loc, exist_ok=True)

# %%
p_list = [["person alpha:"+"\n", 
           "how are you doing?"+"\n", "\n", 
           "person beta:" + "\n"], 
          ["person alpha:"+"\n", 
           "hello there!"+"\n", "\n", 
           "person beta:" + "\n"], 
           ["person alpha:"+"\n", "why does it always seem that "],
           ["person beta:" + "\n"],
]


prompts = ["".join(line) for line in p_list]

# %%
from datetime import datetime
import pprint as pp

ds_date_time = datetime.now().strftime("%m.%d.%Y")

base_header = "gpt-dailydialogue-textgen-{}".format(ds_date_time)
prompt_IDs = [base_header + "_file-{}.txt".format(i+1) for i in range(5, len(prompts)+11)]

prompt_mng = {}
for pid, text in zip(prompt_IDs, prompts):
    prompt_mng[pid] = text
pp.pprint(prompt_mng)

# %%
from os.path import join

for pfile, my_prompt in prompt_mng.items():
    ai.generate_to_file(
        n=50,
        batch_size=5,
        prompt=my_prompt,
        max_length=512,
        temperature=0.8,
        top_p=0.9,
        destination_path=join(save_loc, pfile)
    )
