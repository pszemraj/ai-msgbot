# %% [markdown]
# <a href="https://colab.research.google.com/github/pszemraj/ai-msgbot/blob/main/notebooks/colab-aitextgen/aitextgen_text_generation_and_training_on_GPU.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# #  aitextgen — Train a GPT-2 (or GPT Neo) Text-Generating Model w/ GPU
#
# This notebook is based on the original tutorial from `aitextgen`!
#
# - For more about `aitextgen`, you can visit [this GitHub repository](https://github.com/minimaxir/aitextgen) or [read the documentation](https://docs.aitextgen.io/).
# - for `ai-msgbot` (which is using `aitextgen` for chatbot-esque purposes) you can find the project repo [here](https://github.com/pszemraj/ai-msgbot)
#
#
# _updates made by [Peter](https://peterszemraj.ch/)_

# %% [markdown]
# ---

# %%
#@markdown add auto-Colab formatting with `IPython.display`
from IPython.display import HTML, display
# colab formatting
def set_css():
    display(
        HTML(
            """
  <style>
    pre {
        white-space: pre-wrap;
    }
  </style>
  """
        )
    )

get_ipython().events.register("pre_run_cell", set_css)

# %% [markdown]
# ### GPU
#
# Colaboratory uses a Nvidia K80, an Nvidia P100, an Nvidia V100, or Nvidia A100. For finetuning GPT-2 124M, any of these GPUs will be fine, but for text generation, a k80 or a P100 is ideal since they have more VRAM.
#
# - In theory: **If you receive a T4 or a V100 GPU, you can enable `fp16=True` during training for faster/more memory efficient training.**

# %%
#@title print GPU status
# !nvidia-smi
# Out:
#   <style>
#     pre {
#         white-space: pre-wrap;
#     }
#   </style>
# Sun Jan 23 02:46:25 2022
# +-----------------------------------------------------------------------------+
# | NVIDIA-SMI 495.46       Driver Version: 460.32.03    CUDA Version: 11.2     |
# |-------------------------------+----------------------+----------------------+
# | GPU  Name        Persistence-M| Bus-Id        Disp.A | Volatile Uncorr. ECC |
# | Fan  Temp  Perf  Pwr:Usage/Cap|         Memory-Usage | GPU-Util  Compute M. |
# |                               |                      |               MIG M. |
# |===============================+======================+======================|
# |   0  Tesla V100-SXM2...  Off  | 00000000:00:04.0 Off |                    0 |
# | N/A   32C    P0    49W / 300W |      0MiB / 16160MiB |      0%      Default |
# |                               |                      |                  N/A |
# +-------------------------------+----------------------+----------------------+
#
# +-----------------------------------------------------------------------------+
# | Processes:                                                                  |
# |  GPU   GI   CI        PID   Type   Process name                  GPU Memory |
# |        ID   ID                                                   Usage      |
# |=============================================================================|
# |  No running processes found                                                 |
# +-----------------------------------------------------------------------------+

# %%
#@title print out the VM's CPU stats
from psutil import virtual_memory
import os
ram_gb = round(virtual_memory().total / (1024**3), 1)
print(f'Runtime has {ram_gb} gigs of memory and {os.cpu_count()} processors')

if ram_gb < 20: print("WARNING - your CPU RAM allocated is less than 20.",
                      " You may experience errors loading")
# Out:
#   <style>
#     pre {
#         white-space: pre-wrap;
#     }
#   </style>
# Runtime has 51.0 gigs of memory and 8 processors

# %% [markdown]
# ## setup

# %%
#@title set torch version
# !pip install torch==1.10.0+cu113 torchvision==0.11.1+cu113 -f https://download.pytorch.org/whl/cu113/torch_stable.html -q
# !pip install https://storage.googleapis.com/jax-releases/cuda111/jaxlib-0.1.71+cuda111-cp37-none-manylinux2010_x86_64.whl -q

#@markdown see this issue https://github.com/googlecolab/colabtools/issues/2452 for colab A100 GPU
# Out:
#   <style>
#     pre {
#         white-space: pre-wrap;
#     }
#   </style>

# %%
#@title install aitextgen
# !pip install -q aitextgen

import logging

logging.basicConfig(
    format="%(asctime)s — %(levelname)s — %(name)s — %(message)s",
    datefmt="%m/%d/%Y %H:%M:%S",
    level=logging.INFO,
)

from aitextgen import aitextgen
from aitextgen.colab import mount_gdrive, copy_file_from_gdrive
# Out:
#   <style>
#     pre {
#         white-space: pre-wrap;
#     }
#   </style>

# %%
mount_gdrive()
# Out:
#   <style>
#     pre {
#         white-space: pre-wrap;
#     }
#   </style>
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %% [markdown]
# ### Loading GPT-2 or GPT Neo
#
#
# - A common use case is *continuing* to fine-tune a model that was originally pretrained, and then fine-tuned a little bit, but needs to be fine-tuned more for accuracy/saliency reasons or because Google cut off the runtime earlier.
#     - in this case, `load_from_folder` should be set to `True` and `load_folder_dir` points to where the model checkpoint is on your google drive.
# - **the below section describes loading an new/pretrained model from the original tutorial.**
#
# > If you're retraining a model on new text, you need to download and load the GPT-2 model into the GPU.
#
# > There are several sizes of GPT-2:
#
#     * `124M` (default): the "small" model, 500MB on disk.
#     * `355M` (default): the "medium" model, 1.5GB on disk.
#     * `774M` (default): the "large" model, 3GB on disk.
#
# > You can also finetune a GPT Neo model instead ([_or any textgen GPT-architecture model on huggingface_](https://huggingface.co/models?pipeline_tag=text-generation)), which is more suitable for longer texts and the base model has more recent data:
#
# * `125M`: Analogous to the GPT-2 124M model. (355M parameter model was removed)
# *  `EleutherAI/gpt-neo-1.3B` : 1.3 billion parameter model. Have yet to see this train on Colab without crashing
#
# > The next cell downloads the model and saves it in the Colaboratory VM. If the model has already been downloaded, running this cell will reload it.

# %%
model_size = "355M" #@param ["355M", "774M"]
load_from_folder = False #@param {type:"boolean"}
load_folder_dir = "/content/drive/MyDrive/Programming/ai-msgbot/your-previous-model-name" #@param {type:"string"}
# Out:
#   <style>
#     pre {
#         white-space: pre-wrap;
#     }
#   </style>

# %%
if load_from_folder:
    ai = aitextgen(
        model_folder=load_folder_dir, 
        to_gpu=True,
        gradient_checkpointing=True,
    )
else:
    ai = aitextgen(
        tf_gpt2=model_size, 
        to_gpu=True,
        gradient_checkpointing=True,
    )
# Comment out the above line and uncomment the below line to use GPT Neo instead.

# model_size = "gpt2-xl"
# ai = aitextgen(model='gpt2-xl', 
#                to_gpu=True, 
#                gradient_checkpointing=True)
# Out:
#   <style>
#     pre {
#         white-space: pre-wrap;
#     }
#   </style>
# 01/23/2022 02:46:40 — INFO — aitextgen — Loading 355M GPT-2 model from /aitextgen.
# 01/23/2022 02:46:45 — INFO — aitextgen — GPT2 loaded with 354M parameters.
# 01/23/2022 02:46:45 — INFO — aitextgen — Gradient checkpointing enabled for model training.
# 01/23/2022 02:46:45 — INFO — aitextgen — Using the default GPT-2 Tokenizer.

# %% [markdown]
# ## load training data
#
#
# - links to my parsed data:
#
# ```
# clean "large" whatsapp+iphone text dataset:
#
# https://www.dropbox.com/s/gbk9lkbcx6axk07/clean_apple_and_whatsapp_msgs.txt?dl=1
#
# clean "small" whatsapp+iphone text dataset:
#
# https://www.dropbox.com/s/75hvz74ve2yux02/clean_dataset-V3-whatsapp-apple.txt?dl=1
# ```

# %%
dl_link = "https://github.com/pszemraj/ai-msgbot/raw/main/conversation-data/wizard-of-wikipedia/ScriptParse-wow-train-kilt.txt" #@param {type:"string"}
dataset_tag = "WoW" #@param {type:"string"}
# Out:
#   <style>
#     pre {
#         white-space: pre-wrap;
#     }
#   </style>

# %%
#@markdown retrieve the file behind `dl_link`
from urllib import request
from os.path import join
import os
vm_wd = os.getcwd()
local_name = join(vm_wd, "training_script.txt")
request.urlretrieve(dl_link, local_name)
# Out:
#   <style>
#     pre {
#         white-space: pre-wrap;
#     }
#   </style>
# ('/content/training_script.txt', <http.client.HTTPMessage at 0x7f344fdec190>)

# %%
#@title create the `update_script_names()` and `preview_script()` functions
#@markdown adjust names in script if needed  
import pprint as pp
from os.path import basename

def update_script_names(local_name, spkr_from="speaker a", 
                        spkr_to="person alpha",
                        resp_from="speaker b", resp_to="person beta",
                        verbose=False):
    """
    update_script_names - if the textfile script has different names for the 
    speaker/responder than desired (i.e. it is a group conversation, and the 
    chatbot is just supposed to simulate 1:1) this function can be used to 
    standardize
    """

    with open(local_name, 'r', encoding='utf-8', errors='ignore') as fi:
        orig_lines = fi.readlines()

    from tqdm.auto import tqdm

    upd_lines = []

    for line in tqdm(orig_lines, total=len(orig_lines), 
                     desc="replacing speaker names"):
        
        fixline = line.replace(spkr_from, spkr_to)
        fixline = fixline.replace(resp_from, resp_to)
        upd_lines.append(fixline)

    local_namev2 = join(vm_wd, "V2-rename-" + basename(local_name))

    with open(local_namev2, 'w', encoding='utf-8', errors='ignore') as fo:
        fo.writelines(upd_lines)

    if verbose: pp.pprint(upd_lines[:10])
    # return filepath
    return local_namev2

def preview_script(file_path, num_lines:int=20):
    with open(local_name, 'r', encoding='utf-8', errors='ignore') as fi:
        script_lines = fi.readlines()

    print(f"A preview of the first {num_lines} lines of {file_path} is: \n")
    pp.pprint(script_lines[:num_lines])
# Out:
#   <style>
#     pre {
#         white-space: pre-wrap;
#     }
#   </style>

# %%
local_name = update_script_names(local_name)

file_name = local_name # update if using fn above

preview_script(file_name)
# Out:
#   <style>
#     pre {
#         white-space: pre-wrap;
#     }
#   </style>
# replacing speaker names:   0%|          | 0/1050198 [00:00<?, ?it/s]
# A preview of the first 20 lines of /content/V2-rename-training_script.txt is:
#
# ['person alpha:\n',
#  'i like to watch ice hockey on tv. my favorite team is the chicago '
#  'blackhawks.\n',
#  '\n',
#  'person beta:\n',
#  "the blackhawks are one of my favorite teams, they've won 6 stanley cup "
#  'championships since they started in 1926\n',
#  '\n',
#  'person alpha:\n',
#  'the viking are sea pirates!\n',
#  '\n',
#  'person beta:\n',
#  "i see! didn't they speak the norse language?\n",
#  '\n',
#  'person alpha:\n',
#  "what's the norse language? what country speaks such?\n",
#  '\n',
#  'person beta:\n',
#  'the north germans!\n',
#  '\n',
#  'person alpha:\n',
#  'so what do the vikings do ?are they a cult group?\n']

# %% [markdown]
# ## Train / Finetune GPT-2
#
# The next cell will start the actual finetuning of GPT-2 in aitextgen. It runs for `num_steps`, and a progress bar will appear to show training progress, current loss (the lower the better the model), and average loss (to give a sense on loss trajectory).
#
# The model will be saved every `save_every` steps in `trained_model` by default, and when training completes. If you mounted your Google Drive, the model will _also_ be saved there in a unique folder.
#
# The training might time out after 4ish hours; if you did not mount to Google Drive, make sure you end training and save the results so you don't lose them! (if this happens frequently, you may want to consider using [Colab Pro](https://colab.research.google.com/signup))
#
# Important parameters for `train()`:
#
# - **`line_by_line`**: Set this to `True` if the input text file is a single-column CSV, with one record per row. aitextgen will automatically process it optimally.
# - **`from_cache`**: If you compressed your dataset locally (as noted in the previous section) and are using that cache file, set this to `True`.
# - **`num_steps`**: Number of steps to train the model for.
# - **`generate_every`**: Interval of steps to generate example text from the model; good for qualitatively validating training.
# - **`save_every`**: Interval of steps to save the model: the model will be saved in the VM to `/trained_model`.
# - **`save_gdrive`**: Set this to `True` to copy the model to a unique folder in your Google Drive, if you have mounted it in the earlier cells
# - **`fp16`**: Enables half-precision training for faster/more memory-efficient training. Only works on a T4 or V100 GPU.
#
# Here are other important parameters for `train()` that are useful but you likely do not need to change.
#
# - **`learning_rate`**: Learning rate of the model training.
# - **`batch_size`**: Batch size of the model training; setting it too high will cause the GPU to go OOM. (if using `fp16`, you can increase the batch size more safely)

# %%
import gc, os
from os.path import join
from datetime import datetime
#@title admin params & setup
#@markdown creates folders etc
base_dir = "/content/drive/MyDrive/Programming/ai-msgbot" #@param {type:"string"}
# update to yours
def get_timestamp():
    return datetime.now().strftime("%b-%d-%Y_t-%H")

temp_gpu_path = join(base_dir, 
                     "GPT2-conversational-{sz}-{dt}".format(sz=model_size,
                                                            dt=get_timestamp(),
                                                            )
                     )
os.makedirs(temp_gpu_path, exist_ok=True)
gc.collect()

fp16_kwargs = {
    "amp_backend":'apex'
}
``
#@markdown **tips for training:**<br> do not use warmup steps. 
#@markdown if run OOM, decrease: `batch_size`, `gradient_accumulation_steps`, dataset size (length of text file input). 
#@markdown or increase number of layers frozen.
# Out:
#   <style>
#     pre {
#         white-space: pre-wrap;
#     }
#   </style>

# %%
# DO NOT USE WARMUP STEPS

ai.train(
            file_name, # text file with training data
            output_dir=temp_gpu_path, # where it saves during "save_every"
            line_by_line=False, # if using CSV file input
            from_cache=False,
            num_steps=10000, # takes about 5 hours on 16 gb v100 GPU fo®r 75000
            generate_every=1000,
            max_grad_norm=0.5,
            save_every=1500,
            gradient_accumulation_steps=4,
            save_gdrive=False, # this is an "automated" save which is worse than current method (IMO)
            learning_rate=1e-3,
            # fp16=True, # current bug in aitextgen is MisconfigurationException: You have asked for `amp_level='O1'` but it's only supported with `amp_backend='apex'`.
            batch_size=1, # if pushing model_size you probably want to leave this at 1
            freeze_layers= True, # whether to change weights on ALL layers or not
            num_layers_freeze = 22, # standard GPT-2 M has 24 layers. size L has 36
        #  fp16_opt_level="O2", # different types of FP16 are possible
        )
# Out:
#   <style>
#     pre {
#         white-space: pre-wrap;
#     }
#   </style>
# 01/23/2022 02:46:51 — INFO — aitextgen — Loading text from /content/V2-rename-training_script.txt with generation length of 1024.
#   0%|          | 0/1050198 [00:00<?, ?it/s]
# 01/23/2022 02:46:52 — INFO — aitextgen.TokenDataset — Encoding 1,050,198 sets of tokens from /content/V2-rename-training_script.txt.
# 01/23/2022 02:47:07 — INFO — aitextgen — Layer freezing enabled for model training.
# /usr/local/lib/python3.7/dist-packages/pytorch_lightning/trainer/connectors/callback_connector.py:148: LightningDeprecationWarning: Setting `Trainer(checkpoint_callback=False)` is deprecated in v1.5 and will be removed in v1.7. Please consider using `Trainer(enable_checkpointing=False)`.
#   f"Setting `Trainer(checkpoint_callback={checkpoint_callback})` is deprecated in v1.5 and will "
# /usr/local/lib/python3.7/dist-packages/pytorch_lightning/trainer/connectors/callback_connector.py:91: LightningDeprecationWarning: Setting `Trainer(progress_bar_refresh_rate=20)` is deprecated in v1.5 and will be removed in v1.7. Please pass `pytorch_lightning.callbacks.progress.TQDMProgressBar` with `refresh_rate` directly to the Trainer's `callbacks` argument instead. Or, to disable the progress bar pass `enable_progress_bar = False` to the Trainer.
#   f"Setting `Trainer(progress_bar_refresh_rate={progress_bar_refresh_rate})` is deprecated in v1.5 and"
# /usr/local/lib/python3.7/dist-packages/pytorch_lightning/trainer/connectors/callback_connector.py:168: LightningDeprecationWarning: Setting `Trainer(weights_summary=None)` is deprecated in v1.5 and will be removed in v1.7. Please set `Trainer(enable_model_summary=False)` instead.
#   "Setting `Trainer(weights_summary=None)` is deprecated in v1.5 and will be removed"
# 01/23/2022 02:47:07 — INFO — pytorch_lightning.utilities.distributed — GPU available: True, used: True
# 01/23/2022 02:47:07 — INFO — pytorch_lightning.utilities.distributed — TPU available: False, using: 0 TPU cores
# 01/23/2022 02:47:07 — INFO — pytorch_lightning.utilities.distributed — IPU available: False, using: 0 IPUs
# 01/23/2022 02:47:07 — INFO — pytorch_lightning.accelerators.gpu — LOCAL_RANK: 0 - CUDA_VISIBLE_DEVICES: [0]
#   0%|          | 0/10000 [00:00<?, ?it/s]
# /usr/local/lib/python3.7/dist-packages/pytorch_lightning/trainer/trainer.py:1824: LightningDeprecationWarning: `trainer.progress_bar_dict` is deprecated in v1.5 and will be removed in v1.7. Use `ProgressBarBase.get_metrics` instead.
#   "`trainer.progress_bar_dict` is deprecated in v1.5 and will be removed in v1.7."
# 1,000 steps reached: generating sample texts.
# ==========
#
# person beta:
# yes. what?
#
# person beta:
# well, the original show was based on a tv series and it was based on american literature.
#
# person alpha:
# i just love to play video games, especially on the xbox
#
# person beta:
# it's a great hobby. i love all things electronic, even when it's a hobby.
#
# person alpha:
# i love to play the guitar, do you play guitar as well?
#
# person beta:
# yes, i like to play electric guitars, i think it is the most basic.
#
# person alpha:
# my favorite kind of music is the kind where even though it is a musical composition, it still manages to be a fun and engaging experience.
#
# person beta:
# that sounds like a lot of fun, i do too.
#
# person alpha:
# it's a great way to share your feelings with someone or maybe it's so much fun that you have to keep going.
#
# person beta:
# it is a lot of fun. music has been around for a while so it's hard to pick a favorite.
#
# person alpha:
# i always wanted to be a singer, but i don't think i ever
# ==========
# 1,500 steps reached: saving model to //content/drive/MyDrive/Programming/ai-msgbot/GPT2-conversational-355M-Jan-23-2022_t-02
# 2,000 steps reached: generating sample texts.
# ==========
#
# person alpha:
# i have a friend who is an animator and has a great knack for doing cinematography.
#
# person beta:
# that is awesome, what kind of cinematographer do you use?
#
# person alpha:
# i used to work for a big movie company called the walt disney.
#
# person beta:
# oh, you know that?
#
# person beta:
# it's cool, the walt disney was founded in 1913 by walt disney and became one of the world's largest film studios
#
# person alpha:
# i am a vegetarian. i don't eat pork, fish or any animal flesh.
#
# person beta:
# i am not a vegetarian. i am a carnivore, i like meat.
#
# person alpha:
# i am not sure why vegetarians are called vegetarians. i don't understand. can you tell me more?
#
# person beta:
# vegetarianism was the world's longest-established religious denomination in the late 19th century.
#
# person alpha:
# i don't know anything about vegetarianism, but i do know that they have a lot of respect for animals.
#
# person beta:
# vegetarianism is the practice of
# ==========
# 3,000 steps reached: saving model to //content/drive/MyDrive/Programming/ai-msgbot/GPT2-conversational-355M-Jan-23-2022_t-02
# 3,000 steps reached: generating sample texts.
# ==========
#
# person beta:
# yes, i wonder how many people have used it. theres a lot of people who only use it for their skin care.
#
#
# person beta:
# yes, i am sure a lot of people use it for their skin care. its a bit expensive but i would suggest not to start out with a lot.
#
# person alpha:
# i understand, but when i think of the name of your shampoo, i get a migraine.
#
# person beta:
# it is the most widely used name for a shampoo, im not sure how.
#
# person alpha:
# its a head-shaving facial style in which the head is sucked and then the rest of the body is shaved.
#
# person beta:
# i am not sure why the head-shave is a thing. i think some people do that for cosmetic reasons.
#
# person alpha:
# i think it's more of a fun day-to-day thing.
#
# person beta:
# i heard that the hair that grows on the body is a reflection of the wearer's personality traits.
#
# person alpha:
# i'm a big fan of the beatles, do you know anything about them?
#
# person beta:
# i do
# ==========
# 4,000 steps reached: generating sample texts.
# ==========
#
#
# person alpha:
# oh yeah i am going to go visit the zoo soon, i'm sure i am going to visit the other animals.
#
# person beta:
# they are great! they are great because they are mostly carnivores that eat meat.
#
# person alpha:
# i love to go fishing, it's so fun to go for a walk on the water and you can catch fish.
#
# person beta:
# they are great, its really fun to see the water and try to catch fish with a rod.
#
# person alpha:
# my son was born in october of 1987
#
# person beta:
# that's cool, that is a long time ago! did you go to school during that time?
#
# person alpha:
# yes i did! i did go to houston high school in texas.
#
# person beta:
# oh cool, i had no idea that it was such a long time ago! did you ever have to do homework?
#
# person alpha:
# i did but i did not have a degree in education.
#
# person beta:
# oh no, that's awesome. i know that the term is derived from the old english "man's work" and the greek "man
# ==========
# 4,500 steps reached: saving model to //content/drive/MyDrive/Programming/ai-msgbot/GPT2-conversational-355M-Jan-23-2022_t-02
# 5,000 steps reached: generating sample texts.
# ==========
# no way! i have a dog and he is a canis lupus familiaris
#
# person beta:
# i love mine. they are so sweet
#
# person alpha:
# me too! do you like to go to the beach? i love going to the beach
#
# person beta:
# yes, i go several times a week. i went once and loved going to the beach, it is fun in a beach day. do you like to go to the ocean?
#
# person alpha:
# i like to go to the ocean. i like to swim in the ocean. there is a great body of saline water there.
#
# person beta:
# i like the nature of the beach, it is a land of loose particles of loose particles of water. do you like to swim in the ocean?
#
# person alpha:
# no i love to swim in the ocean too. do you like the ocean?
#
# person beta:
# yes, and i like to swim in the ocean because it is a landform near the shoreline of a body of saline water
#
# person alpha:
# i have a pit bull named max!
#
# person beta:
# oh yeah! i'm not surprised that pit bulls exist. they are the
# ==========
# 6,000 steps reached: saving model to //content/drive/MyDrive/Programming/ai-msgbot/GPT2-conversational-355M-Jan-23-2022_t-02
# 6,000 steps reached: generating sample texts.
# ==========
#
# i have always been a fan of the band. i have been listening to their music since they formed in 1981,
#
# person beta:
# i remember when the band first came out in the 90s i remember loving the band.
#
# person alpha:
# i love going to the beach! the ocean is my favorite place to go to.
#
# person beta:
# me too! i always get a great tanning session.
#
# person alpha:
# i like to hike. the word hiking is actually an old french term for "expertly mounted on a back" which is a lot of fun. have you ever done it?
#
# person beta:
# i have and i think it's a lot of fun! i was never really into it though.
#
# person alpha:
# i actually have never done it. i love to go on the appalachian trials. it's the longest hiking only trail in the world so it's really hard to beat.
#
# person beta:
# i have never done it, but i have seen people doing it.
#
# person beta:
# well i have to go to the appalachian national scenic trail. that's amazing.
#
# person alpha:
# i think i've finally
# ==========
# 7,000 steps reached: generating sample texts.
# ==========
#
# person beta:
# yes i agree. a lot of people don't understand how it works. but it certainly is.
#
# person alpha:
# can you tell me more about the process of learning about the bible?
#
# person beta:
# well, you have to start by reading the books. it is a fairly long process. you can read the books by going through the different books.
#
# person alpha:
# i was thinking of buying a new drum kit. what would you like to know?
#
# person beta:
# the kit is a drum, the acoustic, and usually wood box. it is usually a combination of drums.
#
# person alpha:
# i really like the band yes?
#
# person beta:
# yes, i've heard of them. they are an american rock band from nashville tn
#
# person alpha:
# i have heard of them but do not know their well-known song "it's time"
#
# person beta:
# i have heard of the band yes. i am a fan of their music. but i don't know much about them.
#
# person beta:
# they are an american rock band from a small town, in tennessee
#
# person alpha:
# ==========
# 7,500 steps reached: saving model to //content/drive/MyDrive/Programming/ai-msgbot/GPT2-conversational-355M-Jan-23-2022_t-02
# 8,000 steps reached: generating sample texts.
# ==========
#
# person beta:
# yeah, it's the most common type of food eaten worldwide.
#
# person alpha:
# it is the most consumed food in the world.
#
# person beta:
# yeah, it is! a lot of people try to eat it, but it is very healthy.
#
# person alpha:
# yum. my favorite is the greek salad
#
# person beta:
# my favorite is the pizza, the most common type of pizza, usually with cheese.
#
# person alpha:
# i love going to the museum! i'm sure finding a museum of modern art will be a major find
#
# person beta:
# i agree. the museum of modern art is the largest museums in major cities, and is an important way to explore the museum of modern art.
#
# person alpha:
# i absolutely love to visit museums. i love to see the different museums, and learn about them.
#
# person beta:
# i agree, i love museums too! every museum i visit has something to show me.
#
# person alpha:
# i love to go to the museum of modern art. i love to see the different pieces of modern art from different museums.
#
# person beta:
# i agree, i love museums because
# ==========
# 9,000 steps reached: saving model to //content/drive/MyDrive/Programming/ai-msgbot/GPT2-conversational-355M-Jan-23-2022_t-02
# 9,000 steps reached: generating sample texts.
# ==========
#
# person alpha:
# do you like dogs? i am a dog person myself. i have a poodle.
#
# person beta:
# i love dogs! my dad got a poodle as a newborn puppy from a breeder. it's nice that you have one.
#
# person alpha:
# oh so they are a good size for families? i wonder why some call them "chihuacs"
#
# person beta:
# i don't know about that but it is interesting. they are a good size for families. they have a long association with humans which allowed them to thrive on a starch-rich diet.
#
# person alpha:
# what is the best way to start a relationship?
#
# person beta:
# a good way to start relationships is by going out onto a boat with someone who is looking for a new forever home.
#
# person alpha:
# i am in the navy, they mean waterborne military watercrafts, waterborne military watercrafts
#
# person beta:
# i used to work for the navy, but i now work at an elementary school.
#
# person alpha:
# that's awesome. i never knew that, lol. there's one at my work.
#
# person beta:
# that's
# ==========
# 10,000 steps reached: generating sample texts.
# ==========
#
#
# person alpha:
# do you know how long it has been been around?
#
# person beta:
# of course! i am not sure how long it has been around. but i do know that it is one of the oldest and most extensive skateboards on the planet.
#
# person alpha:
# i also play a lot of video games. do you play any?
#
# person beta:
# i do. i played the arcatics first. the first i ever played was on nintendies 32nd street.
#
# person alpha:
# did you ever play the rpg?
#
# person beta:
# i love the rpg's. i found that the game was very addicting.
#
# person alpha:
# do you know the rules of the game?
#
# person beta:
# no i dont know the rules of the game
#
# person alpha:
# i like to cook.
#
# person beta:
# i love to cook. i'm not great at it myself though.
#
# person alpha:
# i love to cook. i love italian cuisine. i love all the tastes.
#
# person beta:
# i like italian cuisine too. it's so good.
#
# person alpha:
# what do you
# ==========
# 10,500 steps reached: saving model to //content/drive/MyDrive/Programming/ai-msgbot/GPT2-conversational-355M-Jan-23-2022_t-02
# 11,000 steps reached: generating sample texts.
# ==========
#
# person alpha:
# i know, but i was never a big fan of mohammed i am not sure what about him
#
# person beta:
# i used to like him. he was a very popular personality.
#
# person alpha:
# i love to go hiking. it's fun to go on day hikes.
#
# person beta:
# i prefer day hikes in the mountains. did you know he was a teacher?
#
# person alpha:
# no, i didn't know about that. what is a teacher?
#
# person beta:
# i know it was a profession that required teachers to be doctors and technologists
#
# person alpha:
# i love cooking. i usually cook for a living from scratch in my spare time, like i do on the weekends.
#
# person beta:
# that is true. my first recipe called a cookbook was published in 1826 by a french chef.
#
# person alpha:
# i did not know that. i think i'm a little drunk from the time i started playing the game.
#
# person beta:
# i like the cooking part - it is a lot of work. the art is great too. what kind of food do you like?
#
# person alpha:
# i like
# ==========
# 12,000 steps reached: saving model to //content/drive/MyDrive/Programming/ai-msgbot/GPT2-conversational-355M-Jan-23-2022_t-02
# 12,000 steps reached: generating sample texts.
# ==========
#
#
# person beta:
# yes, all you need is a brazillian, which means it means brazille.
#
# person alpha:
# yes, i think brazille is the middle name for the town.
#
# person beta:
# cool, that is interesting. the city of brazille is a port city and was once known for the wine making industry.
#
# person alpha:
# i think i have seen a lot of them over the years.
#
# person beta:
# yes, many famous musicians have contributed to the rollicking musical atmosphere.
#
# person alpha:
# i love pizza so much! it is my favorite food.
#
# person beta:
# me too. it is my favorite food when it's prepared with cheese! what do you like most about it?
#
# person alpha:
# i really like the creamy texture and italian flatbread crust.
#
# person beta:
# i like how it's made, too. what else can you tell me about it?
#
# person alpha:
# well, it's traditionally made from yeasted bread.
#
# person beta:
# that's really interesting. what else can you tell me about it?
#
# person beta:
# pizza was actually invented
# ==========
# 13,000 steps reached: generating sample texts.
# ==========
#  and it was a great book!
#
# person beta:
# it's interesting that the book was published in 1949 so it has a lot of historical and social commentary.
#
# person alpha:
# i am thinking about becoming a lifeguard. can you tell me anything about them?
#
# person beta:
# sure, they're part of the rescue system of a couple of large rivers.
#
# person alpha:
# oh, okay. do they rescue people from drowning or are there a lot of safety nets?
#
# person beta:
# they do have a lot of netting equipment, so i'm sure there would be a good team of divers.
#
# person alpha:
# i think i remember them from childhood.
#
# person beta:
# they are a rescue team. they rescue kids, mostly from drowning or from being swept from a river
#
# person alpha:
# i am a vegetarian, but i don't have a problem with eating meat. are you?
#
# person beta:
# i can respect the ethical treatment of animals. but i'm vegetarian because i think they should be treated that way. do you eat meat?
#
# person alpha:
# i was thinking of becoming a vegetarian when i was in high school. i was thinking
# ==========
# 13,500 steps reached: saving model to //content/drive/MyDrive/Programming/ai-msgbot/GPT2-conversational-355M-Jan-23-2022_t-02
# 14,000 steps reached: generating sample texts.
# ==========
#
# person beta:
# do you know that there is a difference between the two types of paper?
#
# person alpha:
# i'm not sure, i have heard that paper was made by the inland.
#
# person beta:
# oh that's cool, have you ever tried it?
#
# person alpha:
# i'm really into basketball. i'm really into that sport.
#
# person beta:
# basketball is great! it's fun to play!
#
# person beta:
# i love basketball too! it's a limited contact sport that can be played on a rectangular court.
#
# person alpha:
# i am a big fan of the brand i love the brand its a sturdy used when being used as a protective aid too
#
# person beta:
# yeah thats true. what do you know about it?
#
# person alpha:
# well the brand is a great line and has been around since 1948.
#
# person beta:
# oh thats quite a while, that's amazing.
#
# person beta:
# well the brand was founded by louis vuitton in france in 1854 and is still the largest luxury brand in the world.
#
# person alpha:
# i like to run a marathon every morning, i love
# ==========
# 15,000 steps reached: saving model to //content/drive/MyDrive/Programming/ai-msgbot/GPT2-conversational-355M-Jan-23-2022_t-02
# 15,000 steps reached: generating sample texts.
# ==========
#
#
# person beta:
# yes. there's so much to learn about the craft.
#
# person alpha:
# i love food trucks they are so large and amazing
#
# person beta:
# yes they are. what is your favorite food truck?
#
# person alpha:
# i love the large trucks with big vehicles
#
# person beta:
# yes, food trucks are so big.
#
# person beta:
# yes they are. they are so big. food trucks serve millions of people every day!
#
# person alpha:
# i have never been to new york city but i want to move to chicago because of the increasing displacement of people.
#
# person beta:
# i am actually from the midwest and i live in the midwest so what is the big city in the midwest?
#
# person alpha:
# it is actually the third largest metropolitan area in the us.
#
# person beta:
# wow that is cool. what is the big city in the midwest?
#
# person alpha:
# it was named after senator william blake, the 19th president of the united states, from 1828-1830
#
# person beta:
# that is so interesting. what else do you know about that city?
# ==========
# 16,000 steps reached: generating sample texts.
# ==========
#
#
# person alpha:
# what kind of things have you done recently? i love to cook, but am not very good at it
# person beta:
# i have been cooking for about 12 years. i learned how to cook by watching people in restaurants around the world.
#
# person alpha:
# oh, wow that's about how long ago! how many people cook for you?
#
# person beta:
# that's a very long time ago. cooking techniques have changed over the years, from grilling over fires to electric stoves, to baking in various types of ovens.
#
# person alpha:
# haha, i'm not sure if that makes sense, but it is! i love to bake too, and am very much an amateur at it.
#
# person beta:
# that's great that you love to cook and you love to learn, and are good at it! i am sure you have the skills to do it.
#
# person alpha:
# exactly! i feel like i am in a good physical shape. most people are morbidly obese which causes them to have extra body fat.
#
# person beta:
# i'm sorry to hear that. do you ever do any weightlifting?
#
# person alpha:
#
# ==========
# 16,500 steps reached: saving model to //content/drive/MyDrive/Programming/ai-msgbot/GPT2-conversational-355M-Jan-23-2022_t-02
# 17,000 steps reached: generating sample texts.
# ==========
# !
#
# person beta:
# it would be a shame to be stuck in a wheel chair. they're pretty tough.
#
# person alpha:
# yes, they could be, we're not saying they aren't either. i think many do like it though.
#
# person beta:
# there are different types of wheel chair type, they have a seat built in for them like a leather seat.
#
# person alpha:
# i love the color purple, it is my favorite color.
#
# person beta:
# purple is a cool color, i think it's very similar to violet but not quite as intense.
#
# person alpha:
# it is! it's more of a muted color, with similar shades of red and blue
#
# person beta:
# yes, purple is a very cool color, i love to wear it in the color blue.
#
# person beta:
# yea i also love the color purple which is similar to violet but not quite as intense.
#
# person alpha:
# i like to play ultimate sport ultimate frisbee, a non contact team sport played with a flying disc.
#
# person beta:
# yes, it is a non contact sport played with a flying disc.
#
# person alpha:
#
# ==========
# 18,000 steps reached: saving model to //content/drive/MyDrive/Programming/ai-msgbot/GPT2-conversational-355M-Jan-23-2022_t-02
# 18,000 steps reached: generating sample texts.
# ==========
#
#
# person beta:
# yes, i like the color of the light. i like blue.
#
# person alpha:
# i love the fact that it is so bright. my favorite color is red.
#
# person beta:
# me too. it is a great, bright color. what is your favorite colour though?
#
# person alpha:
# i think my favorite color is green. i like green too.
#
# person beta:
# green is the color of the sky and ocean.
#
# person beta:
# oh really, i never knew that!
#
# person alpha:
# that is true, it is also my favorite flower. it's so beautiful.
#
# person beta:
# it is beautiful! my favorite color is red. do you have a favorite color?
#
# person alpha:
# i like blue but you can mix blue with other colors.
#
# person beta:
# i have blue eyes. my favorite shade is nov.
#
# person beta:
# i like blue too. but you can mix blue with other colors
#
# person alpha:
# i know a little about the history of japan. i know it's located in the pacific oean.
#
# person beta:
# what is the population of
# ==========
# 19,000 steps reached: generating sample texts.
# ==========
#
# person beta:
# oh yes, i love to read a good book. i actually have a rather long co-worker who is a huge fan of reading, and she's always been reading. she's always encouraging me to read, and she's so friendly.
#
# person alpha:
# yes, i think that's her kind of funny. it's funny that it's only the older generations that are reading!
#
# person beta:
# i think it's the late 1800s and early 1900s that read the most books.
#
# person alpha:
# i'm always the one who gets the points! i just always get the points. what's your favorite part of reading?
#
# person beta:
# i'm not sure how to choose a favorite, i'm a bit of a rascal myself, but my favorite is the cilvia cahuati series.
#
# person beta:
# is the cilvia cahuati series a classic?
#
# person alpha:
# i'm not sure, but i really like the books by william shakespeare, thomas jefferson and thomas paine.
#
# person beta:
# do you like the shakespeareian version.
#
# person alpha:
# yes, i
# ==========
# 19,500 steps reached: saving model to //content/drive/MyDrive/Programming/ai-msgbot/GPT2-conversational-355M-Jan-23-2022_t-02
# 20,000 steps reached: generating sample texts.
# ==========
#  the city is beautiful from the suburbs.
#
# person beta:
# yes it is. i am from the suburbs of minneapolis-united-states.
#
# person alpha:
# it is the third most populous area of the us
#
# person beta:
# my favorite thing to do in minneapolis is walking
#
# person alpha:
# what kind of animals do you like to see?
#
# person beta:
# i like the bears. they are all domesticated animals.
#
# person alpha:
# i have a pet snake. it is a large, carnivorous reptile. have you ever ridden in one?
#
# person beta:
# i have had them before. they are cute.
#
# person beta:
# yes they are! they are kind of like a legless lizard.
#
# person alpha:
# i have a pit bull! a cat is a pit bull is a cat is a dog is a dog is a pit bull is a shi-dog is a rottweiler is a pit bull is a pit bull is a rottweiler is a rottweiler is a pit bull is a pit bull is a rottweiler is a pit bull is a rottweiler is a rottweiler
# ==========
# 21,000 steps reached: saving model to //content/drive/MyDrive/Programming/ai-msgbot/GPT2-conversational-355M-Jan-23-2022_t-02
# 21,000 steps reached: generating sample texts.
# ==========
#
# person beta:
# i love the woody mountains, they are so beautiful and peaceful.
#
# person alpha:
# i love to drink tea! i have never had it with lemonade.
#
# person beta:
# tea is great, sometimes it's my favorite beverage after water
#
# person alpha:
# i love to read books. it can supply me with ideas.
#
# person beta:
# i don't have cable or satellite tv, so reading is a complex process
#
# person beta:
# yeah it requires a lot of development. it's a means of language acquisition
#
# person alpha:
# yes, i also like reading to help me learn new things.
#
# person beta:
# yes, it's been around a long time, as well as printing, radio, and now internet!
#
# person alpha:
# i have never seen it. i wonder if they still make shirts with the letters japan in it.
#
# person beta:
# i know they have created new names for them in the past, but i would have never guessed that from the name of the company.
#
# person alpha:
# the name does sound familiar. what else can you tell me about this brand?
#
# person beta:
# well
# ==========
# 22,000 steps reached: generating sample texts.
# ==========
#
#
# person beta:
# yes, i have had some people find it useful on their way to work. it's easy to see the difference between the two and i've actually used it on my phone.
#
# person beta:
# that's good, in australia and new zealand they keep heavy metal like metallica and slayer when they play.
#
# person alpha:
# i love the grateful dead.
#
# person beta:
# grateful dead, or anything, is an american rock band formed in 1965
#
# person alpha:
# i've never heard of them, but they've got a good sound.
#
# person beta:
# grateful dead was popular in the us and uk. they were the frontmen of the band fight for the band to continue.
#
# person alpha:
# i have a lot of free time, so i work at night sometimes.
#
# person beta:
# that's cool! i have a lot of free time too. where do you work at night?
#
# person alpha:
# i work at night so i usually work out at night too.
#
# person beta:
# i know. i do the same thing for a living at work.
#
# person alpha:
#
# ==========
# 22,500 steps reached: saving model to //content/drive/MyDrive/Programming/ai-msgbot/GPT2-conversational-355M-Jan-23-2022_t-02
# 23,000 steps reached: generating sample texts.
# ==========
#
# person beta:
# i am not sure when the term "polyamory" was first used, but it seems to have been for some time. it seems like it's been around for a long time.
#
# person alpha:
# i love to eat hamburgers. i love barbecued hamburgers.
#
# person beta:
# i love hamburgers too! i can never go on a hamburger alone, i love the social aspect of the burger.
#
# person alpha:
# i love going on a picnic
#
# person beta:
# i do too. picnic is a romantic thing in the us
#
# person alpha:
# i love going on picnics. i love going on picnics, especially romantic picnics. i like to play the piano, but i don't have any musical/gardening background. do you have a favorite picnic?
#
# person beta:
# i love picnics too. i love to go to them. i love the fact that they have restrooms for you to park and take your food wherever you want, whether you're a restaurant or a picnic.
#
# person alpha:
# i like to go to the beach for a picnic
#
# person beta:
# i like
# ==========
# 24,000 steps reached: saving model to //content/drive/MyDrive/Programming/ai-msgbot/GPT2-conversational-355M-Jan-23-2022_t-02
# 24,000 steps reached: generating sample texts.
# ==========
#  you would think it would be crazy to have your home in the suburbs.
#
# person beta:
# haha, i guess it would be like living in an apartment, which are on the upper side of the street.
#
# person alpha:
# i do not like to draw but i do enjoy sketching and try to make it look interesting to read
#
# person beta:
# i like to draw scenes. i can do it for fun, but i cannot do it for business.
#
# person alpha:
# oh, i suppose you could. it is a great means of communicating visual ideas
#
# person beta:
# it is very easy, but i do not like to do it as a job. it is so hard to do it for a living
#
# person alpha:
# it is, i wish i would get more work out of it
#
# person beta:
# you are right, i am not sure you are either, it is just one of the easiest things in the world to do
#
# person alpha:
# i like to go swimming.
#
# person beta:
# that is cool, i don't like the jogging pools
#
# person alpha:
# i like to go swimming as well.
#
# person beta:
# i
# ==========
# /usr/local/lib/python3.7/dist-packages/pytorch_lightning/trainer/trainer.py:688: UserWarning: Detected KeyboardInterrupt, attempting graceful shutdown...
#   rank_zero_warn("Detected KeyboardInterrupt, attempting graceful shutdown...")
# 01/23/2022 04:29:36 — INFO — aitextgen — Saving trained model pytorch_model.bin to //content/drive/MyDrive/Programming/ai-msgbot/GPT2-conversational-355M-Jan-23-2022_t-02

# %%
#@markdown save results to created folders
import os
from os.path import join
save_path = join(base_dir, 
                     "FIN-GPT-conv-{sz}-{tag}-{dt}".format(sz=model_size,
                                                             tag=dataset_tag,
                                                        dt=get_timestamp(),
                                                        )
                     )

os.makedirs(save_path, exist_ok=True)
ai.save(save_path)

print(f'saved! {get_timestamp()}')
# Out:
#   <style>
#     pre {
#         white-space: pre-wrap;
#     }
#   </style>
# saved! Jan-23-2022_t-04

# %% [markdown]
# You're done! Feel free to go to the **Generate Text From The Trained Model** section to generate text based on your retrained model.

# %% [markdown]
# ---

# %% [markdown]
# # Use a Train Model for Generation
#
# If you already had a trained model from this notebook, running the next cell will copy the `pytorch_model.bin` and the `config.json`file from the specified folder in Google Drive into the Colaboratory VM. (If no `from_folder` is specified, it assumes the two files are located at the root level of your Google Drive)

# %%
# !nvidia-smi
# Out:
#   <style>
#     pre {
#         white-space: pre-wrap;
#     }
#   </style>
# Sun Jan 23 04:29:58 2022
# +-----------------------------------------------------------------------------+
# | NVIDIA-SMI 495.46       Driver Version: 460.32.03    CUDA Version: 11.2     |
# |-------------------------------+----------------------+----------------------+
# | GPU  Name        Persistence-M| Bus-Id        Disp.A | Volatile Uncorr. ECC |
# | Fan  Temp  Perf  Pwr:Usage/Cap|         Memory-Usage | GPU-Util  Compute M. |
# |                               |                      |               MIG M. |
# |===============================+======================+======================|
# |   0  Tesla V100-SXM2...  Off  | 00000000:00:04.0 Off |                    0 |
# | N/A   34C    P0    40W / 300W |  11691MiB / 16160MiB |      0%      Default |
# |                               |                      |                  N/A |
# +-------------------------------+----------------------+----------------------+
#
# +-----------------------------------------------------------------------------+
# | Processes:                                                                  |
# |  GPU   GI   CI        PID   Type   Process name                  GPU Memory |
# |        ID   ID                                                   Usage      |
# |=============================================================================|
# |  No running processes found                                                 |
# +-----------------------------------------------------------------------------+

# %%
# best model thus far @ 1.3B parameters and tuned for 50k steps
# from_folder = "/content/drive/MyDrive/Programming/AI_peter/GPT-Neo-1B-V1"

from_folder = save_path

if len(from_folder) > 2:

    for file in ["pytorch_model.bin", "config.json"]:
        if from_folder:
            copy_file_from_gdrive(file, from_folder)
        else:
            copy_file_from_gdrive(file)

    ai = aitextgen(model_folder=from_folder, to_gpu=True)
else:
    ai = aitextgen(model_folder=".", to_gpu=True)
# Out:
#   <style>
#     pre {
#         white-space: pre-wrap;
#     }
#   </style>
# 01/23/2022 04:30:07 — INFO — aitextgen — Loading model from provided weights and config in //content/drive/MyDrive/Programming/ai-msgbot/FIN-GPT-conv-355M-WoW-Jan-23-2022_t-04.
# /usr/local/lib/python3.7/dist-packages/transformers/configuration_utils.py:349: UserWarning: Passing `gradient_checkpointing` to a config initialization is deprecated and will be removed in v5 Transformers. Using `model.gradient_checkpointing_enable()` instead, or if you are using the `Trainer` API, pass `gradient_checkpointing=True` in your `TrainingArguments`.
#   "Passing `gradient_checkpointing` to a config initialization is deprecated and will be removed in v5 "
# 01/23/2022 04:30:11 — INFO — aitextgen — GPT2 loaded with 354M parameters.
# 01/23/2022 04:30:11 — INFO — aitextgen — Using the default GPT-2 Tokenizer.

# %% [markdown]
# ## Generate Text From The Trained Model

# %% [markdown]
# `generate()` without any parameters generates a single text from the loaded model to the console.

# %%
ai.generate(n=3, max_length=256, 
            temperature=1.0, top_p=0.9)
# Out:
#   <style>
#     pre {
#         white-space: pre-wrap;
#     }
#   </style>
# person alpha:
# yes they are delicious! do you like it with just plain old cheese?
#
# person beta:
# i enjoy that, i think it really is a combination of italian and american.
#
# person alpha:
# i think i prefer my cheese to be on the thick side, and to go with meat like lamb, goat, turkey, etc.
#
# person beta:
# that is an excellent way to go. i enjoy steak to have with a nice marinara sauce or steak and kidney.
#
# person alpha:
# i love to cook new dishes every weekend
#
# person beta:
# me too, the combination of one, two or all is great, but it's weird to think of it as an art.
#
# person alpha:
# i think the only thing that's not as well known is that chefs can make a wide variety of different meals at home.
#
# person beta:
# me too. i'm really not a big fan of the prepackaged food though. i prefer to cook food on the grill, either through the use of an open fire or through electric stoves.
#
# person alpha:
# hello! i live in a rural area and love it. are you from a rural
# ==========
# person alpha:
# i want to get a job in the federal judiciary of the united states
#
# person beta:
# that's great. what do you want to do there?
#
# person beta:
# i would like to be a district attorney, you know? what does that entail?
#
# person alpha:
# i don't like the term "lawyer" but i guess i don't mind it
#
# person beta:
# oh that's fine with you. do you enjoy working as a lawyer?
#
# person alpha:
# i do like working as a lawyer.
#
# person beta:
# there are various paralegals that practice law as a paralegal. what do you like to do?
#
# person alpha:
# i enjoy the paralegal work and the work as an attorney.
#
# person beta:
# what sort of cases does a paralegal typically deal with?
#
# person alpha:
# i think in criminal cases they deal with murder, and also with conspiracy.
#
# person beta:
# did you hear about the new reality show "sense of normalcy" about this case?
#
# person alpha:
# i did, but that was not my favorite episode.
#
# person beta:
#
# ==========
# person beta:
# my favorite dessert is cheesecake but i really love strawberry, chocolate and carmel!
#
# person alpha:
# i love to go snorkeling. what about you?
#
# person beta:
# yes! i snorkel a lot. it's great exercise too.
#
# person alpha:
# do you know anything about the sea life?
#
# person beta:
# i do! we use a marine aquarium at the park. it's a beautiful place. there is plenty of marine plants and animals.
#
# person alpha:
# it's so much better than on land that there isn't much marine plants to protect.
#
# person beta:
# yes, and some of the best seas for snorkeling is in australia and you might want to look into going there.
#
# person alpha:
# that's so cool. is the marine aquarium in australia the same as the ocean?
#
# person beta:
# absolutely. there is a marine park in melbourne, and it's near the city.
#
# person alpha:
# i really love going to the beach, i'm not a swimmer but i like it.
#
# person beta:
# me too! there is nothing better

# %%
ai.generate(prompt="give me a good pickup line!\n person beta:", temperature=1,
            min_length=10, batch_size =20, top_k=6)
# Out:
#   <style>
#     pre {
#         white-space: pre-wrap;
#     }
#   </style>
# give me a good pickup line!
#  person beta:
# well you don't have to have any special knowledge to get the most out of this. you can learn about it online and in stores and in class.
#
# person alpha:
# i love pizza! it is my favorite food, especially with friends over, do you enjoy a nice thin crust?
#
# person beta:
# i absolutely do. i like to fold it in half and eat it like a pizza!
#
# person alpha:
# i like to fold it in half, too, but it sounds kind of gross to eat it that way. do you have a preference on toppings or condiments?
#
# person beta:
# i like pepperoni, mushrooms, sausage, peppers and onions. i also like to put in some good ol' classic pizza
#
# person alpha:
# i love the sound of the violin, i used to play it when i was little!
#
# person beta:
# it's also informally known as a fiddle, and is also informally called a fiddle, as well.
#
# person alpha:
# i love to read, how about you?
#
# person beta:
# i do it for entertainment sometimes. do you have a favorite genre?

# %% [markdown]
# If you're creating an API based on your model and need to pass the generated text elsewhere, you can do `text = ai.generate_one()`
#
# You can also pass in a `prompt` to the generate function to force the text to start with a given character sequence and generate text from there (good if you add an indicator when the text starts).
#
# You can also generate multiple texts at a time by specifing `n`. You can pass a `batch_size` to generate multiple samples in parallel, giving a massive speedup (in Colaboratory, set a maximum of 50 for `batch_size` to avoid going OOM).
#
# Other optional-but-helpful parameters for `ai.generate()` and friends:
#
# *  **`min length`**: The minimum length of the generated text: if the text is shorter than this value after cleanup, aitextgen will generate another one.
# *  **`max_length`**: Number of tokens to generate (default 256, you can generate up to 1024 tokens with GPT-2 and 2048 with GPT Neo)
# * **`temperature`**: The higher the temperature, the crazier the text (default 0.7, recommended to keep between 0.7 and 1.0)
# * **`top_k`**: Limits the generated guesses to the top *k* guesses (default 0 which disables the behavior; if the generated output is super crazy, you may want to set `top_k=40`)
# * **`top_p`**: Nucleus sampling: limits the generated guesses to a cumulative probability. (gets good results on a dataset with `top_p=0.9`)

# %%
ai.generate(
    n=3, batch_size=25, prompt="person beta:\n i just", max_length=256, 
    temperature=1.0, top_p=0.9
)
# Out:
#   <style>
#     pre {
#         white-space: pre-wrap;
#     }
#   </style>
# person beta:
#  i just can't see anyone as an attractive woman! what are some other qualities of a woman you find attractive?
#
# person alpha:
# maybe just some stubby legs or long legs, and a face that is usually not smiling.
#
# person beta:
# that is one of my favorite traits! i never could get past the fact that she was unmarried.
#
# person beta:
# that's why it's interesting that she ended up marrying a guy, which is quite the accomplishment. it's not hard at all.
#
# person alpha:
# do you think that there is anything else you would like to know about a person before they meet them?
#
# person beta:
# people usually date after a few dates, so it's not that difficult to meet someone new. i like to meet someone in person.
#
# person alpha:
# hi, i love hiking! it is so relaxing.
#
# person beta:
# i love hiking too! when was the last time you hiked?
#
# person alpha:
# never, but it has changed a lot in the last few years.
#
# person beta:
# that makes sense, i've heard so many new ideas from the outdoors. is hiking the same as walking or
# ==========
# person beta:
#  i just recently started a workout routine called the ketogenic diet.
#
# person alpha:
# what's a ketogenic diet?
#
# person beta:
# it is a diet that consists of high fats and protein, made up of fats from the ketogenic diet.
#
# person alpha:
# wow, and i don't like meat at all, so is this diet recommended?
#
# person beta:
# well there are variants that have been around for years now.
#
# person alpha:
# i do not like meat at all. have you ever heard of it?
#
# person beta:
# yeah, there is no specifically recommended diet for weight loss.
#
# person alpha:
# okay, that's good. i do not mind eating some fish or meat but no beef or chicken.
#
# person beta:
# yeah i really like steak and beef but not hamburgers or chicken or pork.
#
# person alpha:
# you can also make cauliflower and eggs and keep them refrigerated or frozen.
#
# person beta:
# i also like to put a few quesadillas in my tacos, so that i can make them more often and eat them while i'm making tacos.
#
# person alpha:
# i
# ==========
# person beta:
#  i just love to read novels and comics and comic books, they are my favorite
#
# person alpha:
# me too, they are a lot better than graphic novels. the art forms make a sweet transition to the written word
#
# person beta:
# you can draw on paper and computer monitors and do any color drawing that is not already done with pencil
#
# person beta:
# i agree. it's crazy how much i love doing that. do you think i should be a graphic designer?
#
# person beta:
# well you do not necessarily have to be either, graphic designers are creaters that use experience and technology to make mark-up-free design work on large scale
#
# person alpha:
# i really like dogs!
#
# person beta:
# i love dogs too, they're so attuned to human behavior that they have been bred to be so attuned!
#
# person alpha:
# yep, they are like hunting dogs but they are great. i have three myself!
#
# person beta:
# really? how long have dogs been around?
#
# person beta:
# they are still considered to be man's best friend, because they are so attuned. their diets can help with keeping others well fed.

# %% [markdown]
# For bulk generation, you can generate a large amount of texts to a file and sort out the samples locally on your computer. The next cell will generate `num_files` files, each with `n` texts and whatever other parameters you would pass to `generate()`. The files can then be downloaded from the Files sidebar!
#
# You can rerun the cells as many times as you want for even more generated texts!

# %%
save_loc = "/content/drive/MyDrive/Programming/ai-msgbot/output_files" #@param {type:"string"}
os.makedirs(save_loc, exist_ok=True)
# Out:
#   <style>
#     pre {
#         white-space: pre-wrap;
#     }
#   </style>

# %%
p_list = [
          ["how are you doing?"+"\n", "\n", "person beta:" + "\n"], 
           ["person alpha:"+"\n", "it is obvious that "],
           ["person alpha:"+"\n", "this is ridiculous, "],
           ["person alpha: \n", "can you help me with my homework?"+"\n", "\n", "person beta:" + "\n"],
           ["person beta:" + "\n"],
           ["sarah 'nacho cheese' stanley:" + "\n", 
            "hi! I got a new phone" + "\n",
            "\n",
            "person beta:\n",],
           ["person beta: \n", 
            "Hey I’m meeting the astrophysics professor via zoom after school any tips?"+"\n",
            "\n", 
            "person beta:" + "\n"],
           ["person beta:" + "\n",
            "I know"],
]


prompts = ["".join(line) for line in p_list]
# Out:
#   <style>
#     pre {
#         white-space: pre-wrap;
#     }
#   </style>

# %%
from datetime import datetime
import pprint as pp

ds_date_time = datetime.now().strftime("%m.%d.%Y")

base_header = "gpt-{}-textgen-{}".format(model_size, ds_date_time)
prompt_IDs = [base_header + "_file-{}.txt".format(i) for i in range(1, len(prompts)+1)]

prompt_mng = {}
for pid, text in zip(prompt_IDs, prompts):
    prompt_mng[pid] = text
pp.pprint(prompt_mng)
# Out:
#   <style>
#     pre {
#         white-space: pre-wrap;
#     }
#   </style>
# {'gpt-355M-textgen-01.23.2022_file-1.txt': 'how are you doing?\n'
#                                            '\n'
#                                            'person beta:\n',
#  'gpt-355M-textgen-01.23.2022_file-2.txt': 'person alpha:\nit is obvious that ',
#  'gpt-355M-textgen-01.23.2022_file-3.txt': 'person alpha:\n'
#                                            'this is ridiculous, ',
#  'gpt-355M-textgen-01.23.2022_file-4.txt': 'person alpha: \n'
#                                            'can you help me with my homework?\n'
#                                            '\n'
#                                            'person beta:\n',
#  'gpt-355M-textgen-01.23.2022_file-5.txt': 'person beta:\n',
#  'gpt-355M-textgen-01.23.2022_file-6.txt': "sarah 'nacho cheese' stanley:\n"
#                                            'hi! I got a new phone\n'
#                                            '\n'
#                                            'person beta:\n',
#  'gpt-355M-textgen-01.23.2022_file-7.txt': 'person beta: \n'
#                                            'Hey I’m meeting the astrophysics '
#                                            'professor via zoom after school '
#                                            'any tips?\n'
#                                            '\n'
#                                            'person beta:\n',
#  'gpt-355M-textgen-01.23.2022_file-8.txt': 'person beta:\nI know'}

# %%
from os.path import join

for pfile, my_prompt in prompt_mng.items():
    ai.generate_to_file(
        n=60,
        batch_size=20,
        prompt=my_prompt,
        max_length=512,
        temperature=0.85,
        top_p=0.9,
        destination_path=join(save_loc, pfile)
    )
# Out:
#   <style>
#     pre {
#         white-space: pre-wrap;
#     }
#   </style>
# 01/23/2022 04:33:11 — INFO — aitextgen — Generating 60 texts to /content/drive/MyDrive/Programming/ai-msgbot/output_files/gpt-355M-textgen-01.23.2022_file-1.txt
#   0%|          | 0/60 [00:00<?, ?it/s]
# 01/23/2022 04:33:55 — INFO — aitextgen — Generating 60 texts to /content/drive/MyDrive/Programming/ai-msgbot/output_files/gpt-355M-textgen-01.23.2022_file-2.txt
#   0%|          | 0/60 [00:00<?, ?it/s]
# 01/23/2022 04:34:40 — INFO — aitextgen — Generating 60 texts to /content/drive/MyDrive/Programming/ai-msgbot/output_files/gpt-355M-textgen-01.23.2022_file-3.txt
#   0%|          | 0/60 [00:00<?, ?it/s]
# 01/23/2022 04:35:23 — INFO — aitextgen — Generating 60 texts to /content/drive/MyDrive/Programming/ai-msgbot/output_files/gpt-355M-textgen-01.23.2022_file-4.txt
#   0%|          | 0/60 [00:00<?, ?it/s]
# 01/23/2022 04:36:07 — INFO — aitextgen — Generating 60 texts to /content/drive/MyDrive/Programming/ai-msgbot/output_files/gpt-355M-textgen-01.23.2022_file-5.txt
#   0%|          | 0/60 [00:00<?, ?it/s]
# 01/23/2022 04:36:52 — INFO — aitextgen — Generating 60 texts to /content/drive/MyDrive/Programming/ai-msgbot/output_files/gpt-355M-textgen-01.23.2022_file-6.txt
#   0%|          | 0/60 [00:00<?, ?it/s]
# 01/23/2022 04:37:35 — INFO — aitextgen — Generating 60 texts to /content/drive/MyDrive/Programming/ai-msgbot/output_files/gpt-355M-textgen-01.23.2022_file-7.txt
#   0%|          | 0/60 [00:00<?, ?it/s]
# 01/23/2022 04:38:18 — INFO — aitextgen — Generating 60 texts to /content/drive/MyDrive/Programming/ai-msgbot/output_files/gpt-355M-textgen-01.23.2022_file-8.txt
#   0%|          | 0/60 [00:00<?, ?it/s]
